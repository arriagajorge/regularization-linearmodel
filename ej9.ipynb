# %% [markdown]
# <a href="https://colab.research.google.com/github/arriagajorge/regularization-linearmodel/blob/main/ej9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ISLR2")
install.packages("glmnet")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘iterators’, ‘foreach’, ‘shape’, ‘Rcpp’, ‘RcppEigen’

# %%
library(ISLR2)
library(glmnet)
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-4

# %% [markdown]
# ## lm()

# %%
data("College")
head(College, 2)
str(College)
n <- dim(College)[1]
sum(is.na.data.frame(College)) #no hay NA's

#ajuste lm
lm_simple <- lm(Apps ~ ., data=College)
lm_2 <- lm(Apps ~ .^2, data=College)
lm_2_stepAIC <- step(lm_2, k=2)
lm_2_stepBIC <- step(lm_2, k=log(n))
# Out:
#                              Private Apps Accept Enroll Top10perc Top25perc
# Abilene Christian University Yes     1660 1232   721    23        52
# Adelphi University           Yes     2186 1924   512    16        29
#                              F.Undergrad P.Undergrad Outstate Room.Board Books
# Abilene Christian University 2885         537         7440    3300       450
# Adelphi University           2683        1227        12280    6450       750
#                              Personal PhD Terminal S.F.Ratio perc.alumni Expend
# Abilene Christian University 2200     70  78       18.1      12           7041
# Adelphi University           1500     29  30       12.2      16          10527
#                              Grad.Rate
# Abilene Christian University 60
# Adelphi University           56
# 'data.frame':	777 obs. of  18 variables:
#  $ Private    : Factor w/ 2 levels "No","Yes": 2 2 2 2 2 2 2 2 2 2 ...
#  $ Apps       : num  1660 2186 1428 417 193 ...
#  $ Accept     : num  1232 1924 1097 349 146 ...
#  $ Enroll     : num  721 512 336 137 55 158 103 489 227 172 ...
#  $ Top10perc  : num  23 16 22 60 16 38 17 37 30 21 ...
#  $ Top25perc  : num  52 29 50 89 44 62 45 68 63 44 ...
#  $ F.Undergrad: num  2885 2683 1036 510 249 ...
#  $ P.Undergrad: num  537 1227 99 63 869 ...
#  $ Outstate   : num  7440 12280 11250 12960 7560 ...
#  $ Room.Board : num  3300 6450 3750 5450 4120 ...
#  $ Books      : num  450 750 400 450 800 500 500 450 300 660 ...
#  $ Personal   : num  2200 1500 1165 875 1500 ...
#  $ PhD        : num  70 29 53 92 76 67 90 89 79 40 ...
#  $ Terminal   : num  78 30 66 97 72 73 93 100 84 41 ...
#  $ S.F.Ratio  : num  18.1 12.2 12.9 7.7 11.9 9.4 11.5 13.7 11.3 11.5 ...
#  $ perc.alumni: num  12 16 30 37 2 11 26 37 23 15 ...
#  $ Expend     : num  7041 10527 8735 19016 10922 ...
#  $ Grad.Rate  : num  60 56 54 59 15 55 63 73 80 52 ...
# [1] 0
# Se han truncado las últimas 5000 líneas del flujo de salida.
# - Personal:Expend          1   1918927 277760425 10634
# - Private:Terminal         1   2059885 277901383 10635
# - P.Undergrad:Books        1   2078625 277920123 10635
# - P.Undergrad:S.F.Ratio    1   2192747 278034245 10635
# - Top25perc:S.F.Ratio      1   2242868 278084366 10635
# <none>                                 275841498 10636
# - Top10perc:Terminal       1   2405589 278247087 10636
# - Outstate:S.F.Ratio       1   2408349 278249847 10636
# - Private:S.F.Ratio        1   2574954 278416452 10636
# - Enroll:Top25perc         1   2683211 278524709 10636
# - Top10perc:Outstate       1   2758321 278599819 10636
# - P.Undergrad:Terminal     1   2802393 278643891 10637
# - P.Undergrad:Personal     1   3209151 279050649 10638
# - Accept:Books             1   3428851 279270349 10638
# - F.Undergrad:Room.Board   1   3636557 279478055 10639
# - Top10perc:PhD            1   3700016 279541514 10639
# - F.Undergrad:Outstate     1   3871700 279713198 10640
# - Top25perc:Outstate       1   3913616 279755114 10640
# - Enroll:Grad.Rate         1   4559684 280401182 10642
# - Private:Grad.Rate        1   4846808 280688306 10642
# - Top10perc:S.F.Ratio      1   5078632 280920130 10643
# - Top10perc:perc.alumni    1   5091248 280932746 10643
# - Enroll:Terminal          1   5170453 281011951 10643
# - Accept:F.Undergrad       1   5315043 281156541 10644
# - Enroll:Expend            1   5513373 281354871 10644
# - Accept:Expend            1   5607670 281449168 10644
# - Accept:Grad.Rate         1   6920799 282762297 10648
# - Accept:Top10perc         1   9013884 284855382 10654
# - Enroll:Personal          1   9328352 285169850 10655
# - Enroll:Outstate          1  10410206 286251704 10658
# - Accept:Top25perc         1  11147183 286988681 10660
# - Enroll:Room.Board        1  11508931 287350429 10661
# - F.Undergrad:Personal     1  11622330 287463828 10661
# - Accept:Outstate          1  11939748 287781246 10662
# - F.Undergrad:Books        1  14813576 290655074 10669
# - Top10perc:Grad.Rate      1  15805188 291646686 10672
# - Accept:Room.Board        1  16042929 291884427 10673
# - Enroll:Books             1  17212514 293054012 10676
#
# Step:  AIC=10629.57
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:Terminal + Accept:S.F.Ratio +
#     Accept:Expend + Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:S.F.Ratio +
#     F.Undergrad:perc.alumni + F.Undergrad:Expend + F.Undergrad:Grad.Rate +
#     P.Undergrad:Books + P.Undergrad:Personal + P.Undergrad:PhD +
#     P.Undergrad:Terminal + P.Undergrad:S.F.Ratio + P.Undergrad:perc.alumni +
#     P.Undergrad:Expend + Outstate:Books + Outstate:PhD + Outstate:S.F.Ratio +
#     Outstate:perc.alumni + Room.Board:Books + Room.Board:Personal +
#     Room.Board:PhD + Room.Board:Terminal + Room.Board:S.F.Ratio +
#     Room.Board:Expend + Books:Personal + Books:PhD + Books:Terminal +
#     Books:perc.alumni + Books:Expend + Books:Grad.Rate + Personal:Terminal +
#     Personal:Expend + Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate +
#     S.F.Ratio:Grad.Rate + perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - Accept:Terminal          1    283782 276400034 10624
# - S.F.Ratio:Grad.Rate      1    315435 276431687 10624
# - F.Undergrad:perc.alumni  1    349469 276465720 10624
# - Room.Board:Books         1    365760 276482012 10624
# - F.Undergrad:Expend       1    389307 276505558 10624
# - Private:Accept           1    422165 276538416 10624
# - Top25perc:Books          1    444871 276561122 10624
# - Top10perc:P.Undergrad    1    445698 276561949 10624
# - Room.Board:PhD           1    451488 276567740 10624
# - Outstate:Books           1    501291 276617542 10624
# - Personal:Terminal        1    508253 276624505 10624
# - Books:Grad.Rate          1    588497 276704748 10625
# - PhD:Expend               1    656224 276772475 10625
# - F.Undergrad:S.F.Ratio    1    667894 276784145 10625
# - Top10perc:Expend         1    699418 276815669 10625
# - Top10perc:Top25perc      1    708889 276825140 10625
# - perc.alumni:Expend       1    762980 276879231 10625
# - Top25perc:F.Undergrad    1    781911 276898162 10625
# - PhD:Grad.Rate            1    784294 276900545 10625
# - Top25perc:P.Undergrad    1    792436 276908687 10625
# - Books:perc.alumni        1    797991 276914243 10625
# - Outstate:perc.alumni     1    808929 276925180 10625
# - Top25perc:Personal       1    817651 276933902 10625
# - P.Undergrad:PhD          1    930779 277047030 10626
# - Top10perc:Personal       1    937537 277053788 10626
# - Enroll:P.Undergrad       1    974556 277090807 10626
# - Private:Expend           1    999991 277116242 10626
# - F.Undergrad:P.Undergrad  1   1006547 277122798 10626
# - P.Undergrad:perc.alumni  1   1059778 277176029 10626
# - Outstate:PhD             1   1076280 277192532 10626
# - Enroll:F.Undergrad       1   1077226 277193477 10626
# - F.Undergrad:Grad.Rate    1   1164527 277280778 10626
# - P.Undergrad:Expend       1   1271850 277388102 10626
# - Personal:Grad.Rate       1   1293971 277410222 10627
# - Books:Personal           1   1311649 277427900 10627
# - Top10perc:Books          1   1347640 277463891 10627
# - Room.Board:Terminal      1   1371869 277488121 10627
# - Books:PhD                1   1389643 277505894 10627
# - F.Undergrad:PhD          1   1475322 277591573 10627
# - Room.Board:Personal      1   1480349 277596600 10627
# - Accept:Personal          1   1602636 277718887 10627
# - Books:Expend             1   1655856 277772107 10628
# - Room.Board:S.F.Ratio     1   1673651 277789902 10628
# - Top10perc:F.Undergrad    1   1722903 277839154 10628
# - Accept:S.F.Ratio         1   1769046 277885297 10628
# - Room.Board:Expend        1   1783123 277899374 10628
# - Books:Terminal           1   1790250 277906501 10628
# - Enroll:PhD               1   1854127 277970379 10628
# - F.Undergrad:Terminal     1   1856792 277973043 10628
# - Private:Terminal         1   1902494 278018745 10628
# - Personal:Expend          1   1917929 278034180 10628
# - Enroll:Top10perc         1   1935615 278051866 10628
# - P.Undergrad:Books        1   2129513 278245764 10629
# - P.Undergrad:S.F.Ratio    1   2243436 278359688 10629
# - Top25perc:S.F.Ratio      1   2251161 278367412 10629
# <none>                                 276116251 10630
# - Top10perc:Terminal       1   2375888 278492139 10630
# - Private:S.F.Ratio        1   2439109 278555360 10630
# - Outstate:S.F.Ratio       1   2633452 278749703 10630
# - P.Undergrad:Terminal     1   2781899 278898150 10631
# - Enroll:Top25perc         1   2800388 278916639 10631
# - Top10perc:Outstate       1   3072574 279188825 10632
# - P.Undergrad:Personal     1   3195737 279311988 10632
# - Accept:Books             1   3390337 279506589 10632
# - Top10perc:PhD            1   3585628 279701879 10633
# - F.Undergrad:Room.Board   1   3796578 279912829 10634
# - Top25perc:Outstate       1   4006531 280122782 10634
# - Enroll:Grad.Rate         1   4470516 280586767 10635
# - F.Undergrad:Outstate     1   4515135 280631386 10636
# - Private:Grad.Rate        1   4616769 280733020 10636
# - Top10perc:S.F.Ratio      1   4971346 281087597 10637
# - Enroll:Terminal          1   5055789 281172040 10637
# - Accept:F.Undergrad       1   5057346 281173597 10637
# - Top10perc:perc.alumni    1   5137963 281254214 10637
# - Enroll:Expend            1   5842768 281959020 10639
# - Accept:Expend            1   6360865 282477116 10641
# - Accept:Grad.Rate         1   6648088 282764339 10641
# - Accept:Top10perc         1   9230112 285346363 10648
# - Enroll:Personal          1   9293424 285409676 10649
# - Enroll:Outstate          1  10271605 286387856 10651
# - Accept:Outstate          1  11667668 287783919 10655
# - Accept:Top25perc         1  11685948 287802200 10655
# - F.Undergrad:Personal     1  11704704 287820955 10655
# - Enroll:Room.Board        1  12118724 288234975 10656
# - F.Undergrad:Books        1  14716075 290832326 10663
# - Top10perc:Grad.Rate      1  15628625 291744876 10666
# - Accept:Room.Board        1  16943314 293059565 10669
# - Enroll:Books             1  17037157 293153408 10669
#
# Step:  AIC=10623.72
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:S.F.Ratio +
#     F.Undergrad:perc.alumni + F.Undergrad:Expend + F.Undergrad:Grad.Rate +
#     P.Undergrad:Books + P.Undergrad:Personal + P.Undergrad:PhD +
#     P.Undergrad:Terminal + P.Undergrad:S.F.Ratio + P.Undergrad:perc.alumni +
#     P.Undergrad:Expend + Outstate:Books + Outstate:PhD + Outstate:S.F.Ratio +
#     Outstate:perc.alumni + Room.Board:Books + Room.Board:Personal +
#     Room.Board:PhD + Room.Board:Terminal + Room.Board:S.F.Ratio +
#     Room.Board:Expend + Books:Personal + Books:PhD + Books:Terminal +
#     Books:perc.alumni + Books:Expend + Books:Grad.Rate + Personal:Terminal +
#     Personal:Expend + Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate +
#     S.F.Ratio:Grad.Rate + perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - S.F.Ratio:Grad.Rate      1    278703 276678737 10618
# - Room.Board:Books         1    322235 276722269 10618
# - F.Undergrad:Expend       1    341367 276741401 10618
# - Top10perc:P.Undergrad    1    364901 276764935 10618
# - F.Undergrad:perc.alumni  1    398089 276798123 10618
# - Room.Board:PhD           1    411460 276811494 10618
# - Top25perc:Books          1    468030 276868064 10618
# - Private:Accept           1    523496 276923529 10618
# - Outstate:Books           1    536055 276936088 10619
# - F.Undergrad:S.F.Ratio    1    536243 276936277 10619
# - Personal:Terminal        1    598009 276998042 10619
# - PhD:Expend               1    640725 277040759 10619
# - Books:Grad.Rate          1    674631 277074665 10619
# - Top10perc:Expend         1    679234 277079267 10619
# - Top25perc:P.Undergrad    1    686293 277086327 10619
# - PhD:Grad.Rate            1    695795 277095829 10619
# - Books:perc.alumni        1    749786 277149820 10619
# - Top10perc:Top25perc      1    755388 277155422 10619
# - perc.alumni:Expend       1    769601 277169635 10619
# - Outstate:perc.alumni     1    799751 277199785 10619
# - Top25perc:F.Undergrad    1    809383 277209416 10619
# - Top25perc:Personal       1    858006 277258039 10620
# - P.Undergrad:PhD          1    903754 277303788 10620
# - Enroll:P.Undergrad       1    948356 277348390 10620
# - Enroll:F.Undergrad       1    979903 277379937 10620
# - F.Undergrad:P.Undergrad  1    982113 277382146 10620
# - Top10perc:Personal       1   1005556 277405590 10620
# - Private:Expend           1   1019100 277419133 10620
# - P.Undergrad:perc.alumni  1   1130664 277530698 10620
# - Room.Board:Terminal      1   1181246 277581280 10620
# - Outstate:PhD             1   1185269 277585302 10620
# - P.Undergrad:Expend       1   1268257 277668290 10621
# - Books:PhD                1   1342524 277742558 10621
# - Top10perc:Books          1   1343024 277743058 10621
# - Personal:Grad.Rate       1   1350826 277750859 10621
# - Books:Personal           1   1407217 277807251 10621
# - F.Undergrad:Grad.Rate    1   1436920 277836953 10621
# - Room.Board:Personal      1   1458720 277858753 10621
# - F.Undergrad:PhD          1   1584624 277984658 10622
# - Accept:S.F.Ratio         1   1601707 278001740 10622
# - Room.Board:S.F.Ratio     1   1618447 278018481 10622
# - Room.Board:Expend        1   1679136 278079170 10622
# - Books:Expend             1   1699874 278099908 10622
# - Top10perc:F.Undergrad    1   1747581 278147615 10622
# - Books:Terminal           1   1772700 278172733 10622
# - Private:Terminal         1   1804554 278204588 10622
# - F.Undergrad:Terminal     1   1863688 278263721 10622
# - Personal:Expend          1   1980710 278380743 10623
# - Enroll:PhD               1   2012450 278412483 10623
# - P.Undergrad:Books        1   2034721 278434754 10623
# - P.Undergrad:S.F.Ratio    1   2087209 278487243 10623
# - Enroll:Top10perc         1   2174541 278574575 10623
# - Accept:Personal          1   2220351 278620384 10623
# - Top25perc:S.F.Ratio      1   2287996 278688029 10624
# - Top10perc:Terminal       1   2351386 278751420 10624
# <none>                                 276400034 10624
# - Private:S.F.Ratio        1   2511843 278911877 10624
# - P.Undergrad:Terminal     1   2614686 279014719 10624
# - Outstate:S.F.Ratio       1   2644763 279044796 10624
# - P.Undergrad:Personal     1   2966186 279366220 10625
# - Top10perc:Outstate       1   3168038 279568071 10626
# - Accept:Books             1   3342362 279742395 10626
# - Enroll:Top25perc         1   3592120 279992154 10627
# - F.Undergrad:Room.Board   1   3821919 280221952 10628
# - Top10perc:PhD            1   3905388 280305421 10628
# - Top25perc:Outstate       1   4183189 280583223 10629
# - Private:Grad.Rate        1   4495021 280895055 10630
# - F.Undergrad:Outstate     1   4570448 280970482 10630
# - Accept:F.Undergrad       1   4905858 281305891 10631
# - Top10perc:S.F.Ratio      1   5028567 281428600 10631
# - Enroll:Terminal          1   5047756 281447789 10631
# - Top10perc:perc.alumni    1   5170218 281570252 10632
# - Enroll:Grad.Rate         1   5317250 281717284 10632
# - Enroll:Expend            1   5623443 282023476 10633
# - Accept:Expend            1   6094655 282494688 10634
# - Accept:Grad.Rate         1   7052319 283452353 10637
# - Enroll:Personal          1   9833761 286233795 10644
# - Enroll:Outstate          1  10325066 286725099 10646
# - Accept:Top10perc         1  10404508 286804542 10646
# - F.Undergrad:Personal     1  11440031 287840064 10649
# - Accept:Outstate          1  11710743 288110776 10649
# - Enroll:Room.Board        1  12173541 288573575 10651
# - F.Undergrad:Books        1  14471291 290871324 10657
# - Accept:Top25perc         1  14959330 291359364 10658
# - Top10perc:Grad.Rate      1  15517202 291917235 10660
# - Enroll:Books             1  16762154 293162188 10663
# - Accept:Room.Board        1  17062328 293462361 10664
#
# Step:  AIC=10617.84
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:S.F.Ratio +
#     F.Undergrad:perc.alumni + F.Undergrad:Expend + F.Undergrad:Grad.Rate +
#     P.Undergrad:Books + P.Undergrad:Personal + P.Undergrad:PhD +
#     P.Undergrad:Terminal + P.Undergrad:S.F.Ratio + P.Undergrad:perc.alumni +
#     P.Undergrad:Expend + Outstate:Books + Outstate:PhD + Outstate:S.F.Ratio +
#     Outstate:perc.alumni + Room.Board:Books + Room.Board:Personal +
#     Room.Board:PhD + Room.Board:Terminal + Room.Board:S.F.Ratio +
#     Room.Board:Expend + Books:Personal + Books:PhD + Books:Terminal +
#     Books:perc.alumni + Books:Expend + Books:Grad.Rate + Personal:Terminal +
#     Personal:Expend + Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate +
#     perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - F.Undergrad:Expend       1    339201 277017938 10612
# - Top10perc:P.Undergrad    1    357225 277035962 10612
# - F.Undergrad:perc.alumni  1    369465 277048202 10612
# - Room.Board:Books         1    371277 277050013 10612
# - F.Undergrad:S.F.Ratio    1    429532 277108269 10612
# - Room.Board:PhD           1    436603 277115339 10612
# - Top25perc:Books          1    451842 277130579 10612
# - Outstate:Books           1    483171 277161908 10612
# - Personal:Terminal        1    567056 277245793 10613
# - Private:Accept           1    567066 277245803 10613
# - PhD:Expend               1    634314 277313050 10613
# - Top10perc:Expend         1    636126 277314863 10613
# - PhD:Grad.Rate            1    652088 277330825 10613
# - Top10perc:Top25perc      1    661155 277339892 10613
# - Top25perc:P.Undergrad    1    662007 277340744 10613
# - Books:perc.alumni        1    693607 277372344 10613
# - Books:Grad.Rate          1    719973 277398710 10613
# - Top25perc:F.Undergrad    1    757463 277436200 10613
# - perc.alumni:Expend       1    805271 277484008 10613
# - Outstate:perc.alumni     1    805363 277484100 10613
# - P.Undergrad:PhD          1    808599 277487336 10614
# - Top25perc:Personal       1    827933 277506669 10614
# - Enroll:P.Undergrad       1    927092 277605829 10614
# - Enroll:F.Undergrad       1    941878 277620615 10614
# - F.Undergrad:P.Undergrad  1    977970 277656706 10614
# - Top10perc:Personal       1   1022072 277700809 10614
# - Private:Expend           1   1056903 277735640 10614
# - P.Undergrad:perc.alumni  1   1135506 277814243 10614
# - Room.Board:Terminal      1   1220545 277899282 10615
# - Outstate:PhD             1   1258784 277937521 10615
# - P.Undergrad:Expend       1   1308035 277986772 10615
# - Books:PhD                1   1312587 277991324 10615
# - Top10perc:Books          1   1338535 278017272 10615
# - Personal:Grad.Rate       1   1378882 278057619 10615
# - Room.Board:Personal      1   1381692 278060428 10615
# - Room.Board:S.F.Ratio     1   1388562 278067299 10615
# - Accept:S.F.Ratio         1   1399978 278078715 10615
# - F.Undergrad:Grad.Rate    1   1406226 278084963 10615
# - Room.Board:Expend        1   1513446 278192183 10615
# - Books:Personal           1   1603386 278282123 10616
# - Books:Expend             1   1606078 278284815 10616
# - Books:Terminal           1   1667569 278346306 10616
# - F.Undergrad:PhD          1   1681931 278360668 10616
# - Top10perc:F.Undergrad    1   1684252 278362989 10616
# - F.Undergrad:Terminal     1   1865382 278544118 10616
# - Private:Terminal         1   2006191 278684928 10617
# - P.Undergrad:Books        1   2035073 278713810 10617
# - Personal:Expend          1   2063912 278742649 10617
# - Enroll:PhD               1   2093369 278772106 10617
# - Top25perc:S.F.Ratio      1   2165773 278844509 10617
# - Enroll:Top10perc         1   2229415 278908151 10617
# - P.Undergrad:S.F.Ratio    1   2273333 278952069 10618
# - Accept:Personal          1   2312297 278991034 10618
# <none>                                 276678737 10618
# - P.Undergrad:Terminal     1   2447233 279125970 10618
# - Top10perc:Terminal       1   2500551 279179288 10618
# - Private:S.F.Ratio        1   2510457 279189194 10618
# - Outstate:S.F.Ratio       1   2696672 279375409 10619
# - P.Undergrad:Personal     1   2950135 279628872 10619
# - Top10perc:Outstate       1   3060714 279739451 10620
# - Accept:Books             1   3203556 279882292 10620
# - Enroll:Top25perc         1   3527744 280206481 10621
# - F.Undergrad:Room.Board   1   3902773 280581510 10622
# - Top10perc:PhD            1   4091454 280770190 10623
# - Top25perc:Outstate       1   4103139 280781876 10623
# - Private:Grad.Rate        1   4239547 280918284 10623
# - F.Undergrad:Outstate     1   4501464 281180200 10624
# - Accept:F.Undergrad       1   4794447 281473184 10624
# - Enroll:Terminal          1   5026680 281705417 10625
# - Top10perc:S.F.Ratio      1   5084533 281763270 10625
# - Top10perc:perc.alumni    1   5439626 282118363 10626
# - Enroll:Grad.Rate         1   5581612 282260349 10627
# - Enroll:Expend            1   5671200 282349937 10627
# - Accept:Expend            1   6222669 282901406 10628
# - Accept:Grad.Rate         1   7392688 284071425 10632
# - Enroll:Personal          1   9806716 286485453 10638
# - Accept:Top10perc         1  10312813 286991550 10640
# - Enroll:Outstate          1  10355390 287034126 10640
# - F.Undergrad:Personal     1  11261027 287939764 10642
# - Accept:Outstate          1  11967555 288646291 10644
# - Enroll:Room.Board        1  12338354 289017090 10645
# - F.Undergrad:Books        1  14250187 290928924 10650
# - Accept:Top25perc         1  14695819 291374556 10651
# - Enroll:Books             1  16499652 293178389 10656
# - Accept:Room.Board        1  17224108 293902845 10658
# - Top10perc:Grad.Rate      1  17246518 293925255 10658
#
# Step:  AIC=10612.14
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:S.F.Ratio +
#     F.Undergrad:perc.alumni + F.Undergrad:Grad.Rate + P.Undergrad:Books +
#     P.Undergrad:Personal + P.Undergrad:PhD + P.Undergrad:Terminal +
#     P.Undergrad:S.F.Ratio + P.Undergrad:perc.alumni + P.Undergrad:Expend +
#     Outstate:Books + Outstate:PhD + Outstate:S.F.Ratio + Outstate:perc.alumni +
#     Room.Board:Books + Room.Board:Personal + Room.Board:PhD +
#     Room.Board:Terminal + Room.Board:S.F.Ratio + Room.Board:Expend +
#     Books:Personal + Books:PhD + Books:Terminal + Books:perc.alumni +
#     Books:Expend + Books:Grad.Rate + Personal:Terminal + Personal:Expend +
#     Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate + perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - F.Undergrad:S.F.Ratio    1    264147 277282085 10606
# - F.Undergrad:perc.alumni  1    293861 277311799 10606
# - Room.Board:Books         1    350494 277368432 10606
# - Top10perc:P.Undergrad    1    366606 277384544 10606
# - Room.Board:PhD           1    455175 277473113 10607
# - Top25perc:Books          1    474888 277492826 10607
# - Outstate:Books           1    502613 277520551 10607
# - PhD:Expend               1    552593 277570531 10607
# - Top25perc:F.Undergrad    1    560722 277578660 10607
# - Personal:Terminal        1    586881 277604819 10607
# - Top10perc:Expend         1    619285 277637223 10607
# - Private:Accept           1    624633 277642571 10607
# - Top25perc:P.Undergrad    1    664195 277682133 10607
# - PhD:Grad.Rate            1    672970 277690908 10607
# - Books:Grad.Rate          1    701835 277719773 10608
# - Outstate:perc.alumni     1    726538 277744476 10608
# - Books:perc.alumni        1    731351 277749289 10608
# - P.Undergrad:PhD          1    731500 277749438 10608
# - Top10perc:Top25perc      1    754508 277772446 10608
# - Top25perc:Personal       1    883523 277901461 10608
# - Enroll:F.Undergrad       1    885472 277903410 10608
# - P.Undergrad:perc.alumni  1    947201 277965140 10608
# - P.Undergrad:Expend       1   1013003 278030942 10608
# - perc.alumni:Expend       1   1028934 278046872 10608
# - Top10perc:Personal       1   1119776 278137715 10609
# - F.Undergrad:P.Undergrad  1   1128773 278146711 10609
# - Enroll:P.Undergrad       1   1138330 278156269 10609
# - F.Undergrad:Grad.Rate    1   1205341 278223279 10609
# - Accept:S.F.Ratio         1   1216450 278234388 10609
# - Outstate:PhD             1   1224282 278242220 10609
# - Room.Board:Terminal      1   1290613 278308551 10609
# - Books:PhD                1   1332936 278350874 10609
# - Top10perc:Books          1   1341808 278359746 10609
# - Top10perc:F.Undergrad    1   1348687 278366626 10609
# - Personal:Grad.Rate       1   1382957 278400895 10609
# - Private:Expend           1   1418995 278436933 10610
# - Room.Board:Personal      1   1451538 278469476 10610
# - Room.Board:S.F.Ratio     1   1486230 278504168 10610
# - Room.Board:Expend        1   1581701 278599639 10610
# - Books:Personal           1   1615771 278633710 10610
# - Books:Expend             1   1657341 278675279 10610
# - Books:Terminal           1   1729729 278747667 10610
# - F.Undergrad:Terminal     1   1743539 278761477 10610
# - F.Undergrad:PhD          1   2085951 279103889 10611
# - Personal:Expend          1   2134781 279152719 10612
# - Private:Terminal         1   2192135 279210074 10612
# - Accept:Personal          1   2207864 279225802 10612
# - P.Undergrad:S.F.Ratio    1   2224126 279242064 10612
# - P.Undergrad:Books        1   2228834 279246773 10612
# - Top25perc:S.F.Ratio      1   2231671 279249609 10612
# <none>                                 277017938 10612
# - P.Undergrad:Terminal     1   2483295 279501233 10612
# - Enroll:PhD               1   2520218 279538156 10612
# - Top10perc:Terminal       1   2660758 279678696 10613
# - Outstate:S.F.Ratio       1   2795151 279813089 10613
# - Top10perc:Outstate       1   2954295 279972233 10614
# - P.Undergrad:Personal     1   2973429 279991367 10614
# - Private:S.F.Ratio        1   2990584 280008522 10614
# - Accept:Books             1   3169757 280187695 10614
# - F.Undergrad:Room.Board   1   3603304 280621242 10616
# - Enroll:Top10perc         1   4024641 281042579 10617
# - Top25perc:Outstate       1   4060354 281078292 10617
# - Top10perc:PhD            1   4438348 281456286 10618
# - Private:Grad.Rate        1   4549655 281567594 10618
# - Enroll:Top25perc         1   4768947 281786885 10619
# - Accept:F.Undergrad       1   4789874 281807812 10619
# - Enroll:Terminal          1   4895905 281913844 10619
# - Top10perc:S.F.Ratio      1   5188108 282206046 10620
# - F.Undergrad:Outstate     1   5209840 282227778 10620
# - Enroll:Grad.Rate         1   5343241 282361179 10620
# - Top10perc:perc.alumni    1   5747234 282765172 10621
# - Accept:Expend            1   5883540 282901478 10622
# - Accept:Grad.Rate         1   7424762 284442700 10626
# - Enroll:Personal          1   9789624 286807562 10632
# - Accept:Top10perc         1  11102064 288120002 10636
# - F.Undergrad:Personal     1  11599555 288617493 10637
# - Enroll:Outstate          1  11896711 288914649 10638
# - Enroll:Room.Board        1  12032930 289050868 10638
# - Accept:Outstate          1  12314341 289332279 10639
# - F.Undergrad:Books        1  15017032 292034970 10646
# - Accept:Top25perc         1  15307889 292325827 10647
# - Enroll:Expend            1  16737218 293755156 10651
# - Accept:Room.Board        1  16897093 293915031 10652
# - Enroll:Books             1  16978504 293996442 10652
# - Top10perc:Grad.Rate      1  17667817 294685756 10654
#
# Step:  AIC=10606.23
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:perc.alumni +
#     F.Undergrad:Grad.Rate + P.Undergrad:Books + P.Undergrad:Personal +
#     P.Undergrad:PhD + P.Undergrad:Terminal + P.Undergrad:S.F.Ratio +
#     P.Undergrad:perc.alumni + P.Undergrad:Expend + Outstate:Books +
#     Outstate:PhD + Outstate:S.F.Ratio + Outstate:perc.alumni +
#     Room.Board:Books + Room.Board:Personal + Room.Board:PhD +
#     Room.Board:Terminal + Room.Board:S.F.Ratio + Room.Board:Expend +
#     Books:Personal + Books:PhD + Books:Terminal + Books:perc.alumni +
#     Books:Expend + Books:Grad.Rate + Personal:Terminal + Personal:Expend +
#     Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate + perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - F.Undergrad:perc.alumni  1    300326 277582411 10600
# - Room.Board:Books         1    343467 277625552 10600
# - Top10perc:P.Undergrad    1    369966 277652051 10601
# - Room.Board:PhD           1    452446 277734530 10601
# - Outstate:Books           1    479118 277761203 10601
# - Top25perc:Books          1    506570 277788655 10601
# - PhD:Expend               1    550143 277832227 10601
# - Personal:Terminal        1    591551 277873636 10601
# - Private:Accept           1    616982 277899067 10601
# - Enroll:F.Undergrad       1    633263 277915347 10601
# - Top25perc:P.Undergrad    1    665049 277947134 10601
# - PhD:Grad.Rate            1    670870 277952955 10601
# - Books:Grad.Rate          1    677116 277959201 10602
# - Top25perc:F.Undergrad    1    706906 277988991 10602
# - Top10perc:Expend         1    706963 277989048 10602
# - Top10perc:Top25perc      1    711109 277993194 10602
# - Books:perc.alumni        1    750307 278032392 10602
# - Outstate:perc.alumni     1    765430 278047515 10602
# - P.Undergrad:PhD          1    792549 278074634 10602
# - Top25perc:Personal       1    802189 278084274 10602
# - P.Undergrad:perc.alumni  1   1029505 278311589 10602
# - perc.alumni:Expend       1   1037313 278319398 10602
# - Top10perc:Personal       1   1048250 278330335 10602
# - Enroll:P.Undergrad       1   1053262 278335347 10602
# - P.Undergrad:Expend       1   1054042 278336127 10602
# - F.Undergrad:P.Undergrad  1   1061735 278343820 10602
# - Outstate:PhD             1   1170463 278452547 10603
# - F.Undergrad:Grad.Rate    1   1192286 278474371 10603
# - Room.Board:Terminal      1   1254931 278537016 10603
# - Personal:Grad.Rate       1   1256563 278538647 10603
# - Books:PhD                1   1365243 278647328 10603
# - Top10perc:Books          1   1427327 278709411 10604
# - Private:Expend           1   1492099 278774184 10604
# - Room.Board:Personal      1   1505708 278787793 10604
# - Accept:S.F.Ratio         1   1509668 278791753 10604
# - F.Undergrad:Terminal     1   1591616 278873700 10604
# - Books:Personal           1   1605686 278887771 10604
# - Books:Expend             1   1618838 278900923 10604
# - Top10perc:F.Undergrad    1   1620947 278903032 10604
# - Room.Board:Expend        1   1687478 278969563 10604
# - Room.Board:S.F.Ratio     1   1719163 279001248 10604
# - Books:Terminal           1   1765898 279047983 10604
# - F.Undergrad:PhD          1   1914169 279196254 10605
# - P.Undergrad:S.F.Ratio    1   1960549 279242634 10605
# - Accept:Personal          1   2171792 279453877 10606
# - Personal:Expend          1   2176953 279459038 10606
# - Top25perc:S.F.Ratio      1   2192536 279474621 10606
# - P.Undergrad:Books        1   2204724 279486809 10606
# - Private:Terminal         1   2205342 279487426 10606
# - Enroll:PhD               1   2369889 279651974 10606
# <none>                                 277282085 10606
# - P.Undergrad:Terminal     1   2494116 279776201 10606
# - Outstate:S.F.Ratio       1   2667996 279950081 10607
# - Top10perc:Terminal       1   2670837 279952921 10607
# - Top10perc:Outstate       1   2896867 280178951 10608
# - P.Undergrad:Personal     1   2972049 280254134 10608
# - Accept:Books             1   3150042 280432127 10608
# - Private:S.F.Ratio        1   3406821 280688905 10609
# - F.Undergrad:Room.Board   1   3418734 280700819 10609
# - Enroll:Top10perc         1   3770438 281052523 10610
# - Top25perc:Outstate       1   3937581 281219666 10610
# - Top10perc:PhD            1   4321240 281603325 10612
# - Private:Grad.Rate        1   4476531 281758616 10612
# - Enroll:Top25perc         1   4521164 281803249 10612
# - Enroll:Terminal          1   4672821 281954906 10613
# - Accept:F.Undergrad       1   4723378 282005463 10613
# - F.Undergrad:Outstate     1   4949947 282232032 10613
# - Enroll:Grad.Rate         1   5239848 282521933 10614
# - Top10perc:S.F.Ratio      1   5367272 282649356 10614
# - Top10perc:perc.alumni    1   5857517 283139602 10616
# - Accept:Grad.Rate         1   7381762 284663847 10620
# - Accept:Expend            1   7902205 285184290 10621
# - Enroll:Personal          1   9543926 286826011 10626
# - Accept:Top10perc         1  10953182 288235266 10630
# - F.Undergrad:Personal     1  11349457 288631542 10631
# - Enroll:Outstate          1  11633326 288915410 10632
# - Enroll:Room.Board        1  11937309 289219394 10632
# - Accept:Outstate          1  12661157 289943242 10634
# - F.Undergrad:Books        1  14771246 292053330 10640
# - Accept:Top25perc         1  15202382 292484467 10641
# - Enroll:Books             1  16727286 294009370 10645
# - Accept:Room.Board        1  17231574 294513658 10646
# - Top10perc:Grad.Rate      1  17634966 294917051 10648
# - Enroll:Expend            1  21958066 299240151 10659
#
# Step:  AIC=10600.41
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:Grad.Rate +
#     P.Undergrad:Books + P.Undergrad:Personal + P.Undergrad:PhD +
#     P.Undergrad:Terminal + P.Undergrad:S.F.Ratio + P.Undergrad:perc.alumni +
#     P.Undergrad:Expend + Outstate:Books + Outstate:PhD + Outstate:S.F.Ratio +
#     Outstate:perc.alumni + Room.Board:Books + Room.Board:Personal +
#     Room.Board:PhD + Room.Board:Terminal + Room.Board:S.F.Ratio +
#     Room.Board:Expend + Books:Personal + Books:PhD + Books:Terminal +
#     Books:perc.alumni + Books:Expend + Books:Grad.Rate + Personal:Terminal +
#     Personal:Expend + Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate +
#     perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - Room.Board:Books         1    282519 277864929 10594
# - Top10perc:P.Undergrad    1    390943 277973353 10595
# - Room.Board:PhD           1    428079 278010490 10595
# - Outstate:Books           1    458292 278040703 10595
# - Top25perc:Books          1    471254 278053665 10595
# - PhD:Expend               1    517232 278099643 10595
# - Private:Accept           1    533361 278115772 10595
# - Personal:Terminal        1    573750 278156160 10595
# - Outstate:perc.alumni     1    637004 278219415 10596
# - PhD:Grad.Rate            1    641320 278223731 10596
# - Top25perc:F.Undergrad    1    664173 278246583 10596
# - Top10perc:Top25perc      1    671602 278254012 10596
# - Enroll:F.Undergrad       1    689324 278271735 10596
# - Books:Grad.Rate          1    702906 278285317 10596
# - Books:perc.alumni        1    718021 278300431 10596
# - P.Undergrad:PhD          1    719132 278301543 10596
# - P.Undergrad:perc.alumni  1    734862 278317272 10596
# - Top10perc:Expend         1    745012 278327423 10596
# - Top25perc:P.Undergrad    1    794904 278377315 10596
# - Top25perc:Personal       1    805981 278388391 10596
# - Enroll:P.Undergrad       1    856185 278438596 10596
# - P.Undergrad:Expend       1    858652 278441063 10596
# - F.Undergrad:P.Undergrad  1    905781 278488192 10596
# - perc.alumni:Expend       1   1024947 278607358 10597
# - Top10perc:Personal       1   1039535 278621945 10597
# - Outstate:PhD             1   1172950 278755361 10597
# - F.Undergrad:Grad.Rate    1   1174581 278756991 10597
# - Personal:Grad.Rate       1   1204962 278787373 10597
# - Room.Board:Terminal      1   1226272 278808682 10597
# - Books:PhD                1   1273071 278855482 10597
# - Top10perc:Books          1   1342509 278924919 10598
# - Room.Board:Personal      1   1469934 279052345 10598
# - Private:Expend           1   1510315 279092726 10598
# - F.Undergrad:Terminal     1   1539521 279121931 10598
# - Books:Expend             1   1616097 279198508 10598
# - Books:Personal           1   1618224 279200634 10598
# - Top10perc:F.Undergrad    1   1622712 279205122 10598
# - Accept:S.F.Ratio         1   1650428 279232839 10598
# - Books:Terminal           1   1679725 279262135 10598
# - Room.Board:Expend        1   1792980 279375390 10599
# - P.Undergrad:S.F.Ratio    1   1868208 279450619 10599
# - Room.Board:S.F.Ratio     1   1897099 279479510 10599
# - F.Undergrad:PhD          1   1981894 279564305 10599
# - P.Undergrad:Books        1   1999035 279581446 10599
# - Personal:Expend          1   2121886 279704296 10600
# - Private:Terminal         1   2195598 279778008 10600
# - Top25perc:S.F.Ratio      1   2207087 279789497 10600
# <none>                                 277582411 10600
# - Accept:Personal          1   2393339 279975750 10600
# - Enroll:PhD               1   2404080 279986490 10600
# - P.Undergrad:Terminal     1   2615476 280197887 10601
# - Top10perc:Terminal       1   2670169 280252580 10601
# - Outstate:S.F.Ratio       1   2911365 280493775 10602
# - Top10perc:Outstate       1   2924792 280507203 10602
# - P.Undergrad:Personal     1   3003149 280585560 10602
# - Accept:Books             1   3344279 280926690 10603
# - F.Undergrad:Room.Board   1   3381899 280964309 10603
# - Private:S.F.Ratio        1   3584104 281166515 10604
# - Top25perc:Outstate       1   3893320 281475731 10605
# - Enroll:Top10perc         1   3900158 281482568 10605
# - Top10perc:PhD            1   4405203 281987614 10606
# - Enroll:Top25perc         1   4495218 282077628 10606
# - Private:Grad.Rate        1   4510559 282092969 10606
# - Enroll:Terminal          1   4619212 282201622 10607
# - Accept:F.Undergrad       1   4818574 282400985 10607
# - F.Undergrad:Outstate     1   4973888 282556298 10608
# - Enroll:Grad.Rate         1   5310478 282892889 10608
# - Top10perc:S.F.Ratio      1   5353518 282935928 10609
# - Top10perc:perc.alumni    1   5575041 283157452 10609
# - Accept:Grad.Rate         1   7701223 285283634 10615
# - Accept:Expend            1   7884808 285467218 10616
# - Enroll:Personal          1   9592029 287174440 10620
# - F.Undergrad:Personal     1  11106748 288689159 10624
# - Accept:Top10perc         1  11219966 288802377 10624
# - Enroll:Outstate          1  11760879 289343290 10626
# - Enroll:Room.Board        1  12119945 289702356 10627
# - Accept:Outstate          1  12771126 290353537 10629
# - F.Undergrad:Books        1  14553740 292136150 10634
# - Accept:Top25perc         1  15280115 292862526 10635
# - Enroll:Books             1  16855660 294438070 10640
# - Top10perc:Grad.Rate      1  17396056 294978466 10641
# - Accept:Room.Board        1  17509738 295092148 10641
# - Enroll:Expend            1  22234340 299816751 10654
#
# Step:  AIC=10594.55
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     PhD + Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Accept + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:P.Undergrad + Top10perc:Outstate +
#     Top10perc:Books + Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:P.Undergrad +
#     Top25perc:Outstate + Top25perc:Books + Top25perc:Personal +
#     Top25perc:S.F.Ratio + F.Undergrad:P.Undergrad + F.Undergrad:Outstate +
#     F.Undergrad:Room.Board + F.Undergrad:Books + F.Undergrad:Personal +
#     F.Undergrad:PhD + F.Undergrad:Terminal + F.Undergrad:Grad.Rate +
#     P.Undergrad:Books + P.Undergrad:Personal + P.Undergrad:PhD +
#     P.Undergrad:Terminal + P.Undergrad:S.F.Ratio + P.Undergrad:perc.alumni +
#     P.Undergrad:Expend + Outstate:Books + Outstate:PhD + Outstate:S.F.Ratio +
#     Outstate:perc.alumni + Room.Board:Personal + Room.Board:PhD +
#     Room.Board:Terminal + Room.Board:S.F.Ratio + Room.Board:Expend +
#     Books:Personal + Books:PhD + Books:Terminal + Books:perc.alumni +
#     Books:Expend + Books:Grad.Rate + Personal:Terminal + Personal:Expend +
#     Personal:Grad.Rate + PhD:Expend + PhD:Grad.Rate + perc.alumni:Expend
#
#                           Df Sum of Sq       RSS   AIC
# - Outstate:Books           1    298115 278163044 10589
# - Top10perc:P.Undergrad    1    424094 278289024 10589
# - Top25perc:Books          1    449413 278314342 10589
# - PhD:Expend               1    488148 278353077 10589
# - Room.Board:PhD           1    523500 278388429 10589
# - Personal:Terminal        1    543473 278408403 10589
# - Private:Accept           1    602006 278466936 10590
# - Books:perc.alumni        1    602854 278467783 10590
# - Enroll:F.Undergrad       1    646429 278511359 10590
# - Top10perc:Top25perc      1    654795 278519724 10590
# - PhD:Grad.Rate            1    660834 278525764 10590
# - Top25perc:F.Undergrad    1    672031 278536960 10590
# - P.Undergrad:PhD          1    703058 278567988 10590
# - P.Undergrad:perc.alumni  1    707268 278572197 10590
# - Outstate:perc.alumni     1    709442 278574371 10590
# - Top10perc:Expend         1    751883 278616812 10590
# - Books:Grad.Rate          1    768337 278633266 10590
# - Top25perc:Personal       1    798409 278663338 10590
# - P.Undergrad:Expend       1    806629 278671559 10590
# - Top25perc:P.Undergrad    1    814445 278679375 10590
# - Enroll:P.Undergrad       1    868581 278733511 10590
# - F.Undergrad:P.Undergrad  1    906051 278770980 10590
# ...
#     Top25perc:S.F.Ratio + F.Undergrad:Outstate + F.Undergrad:Room.Board +
#     F.Undergrad:Books + F.Undergrad:Personal + P.Undergrad:Books +
#     P.Undergrad:Personal + Outstate:S.F.Ratio + Room.Board:S.F.Ratio +
#     Room.Board:Expend + perc.alumni:Expend
#
#                          Df Sum of Sq       RSS   AIC
# - Room.Board:Expend       1   1681163 319032053 10382
# - Top25perc:F.Undergrad   1   2210758 319561648 10384
# - Private:Terminal        1   2497082 319847972 10384
# <none>                                317350890 10385
# - F.Undergrad:Room.Board  1   2848207 320199098 10385
# - F.Undergrad:Outstate    1   3673652 321024542 10387
# - Accept:Books            1   3822560 321173450 10388
# - Room.Board:S.F.Ratio    1   4045082 321395972 10388
# - perc.alumni:Expend      1   4064316 321415206 10388
# - Top10perc:perc.alumni   1   4453074 321803964 10389
# - Enroll:Top10perc        1   4635315 321986206 10390
# - P.Undergrad:Books       1   4768538 322119428 10390
# - Enroll:Personal         1   5510628 322861518 10392
# - Top10perc:F.Undergrad   1   6093111 323444001 10393
# - Outstate:S.F.Ratio      1   6107425 323458315 10393
# - Enroll:Terminal         1   6171947 323522837 10393
# - Enroll:Top25perc        1   6375015 323725905 10394
# - Accept:Grad.Rate        1   6547444 323898334 10394
# - P.Undergrad:Personal    1   6964845 324315735 10395
# - Enroll:Grad.Rate        1   7059489 324410379 10395
# - Top25perc:S.F.Ratio     1   8120689 325471579 10398
# - Accept:F.Undergrad      1   8148017 325498907 10398
# - Private:Grad.Rate       1   8508380 325859270 10399
# - F.Undergrad:Personal    1   8650144 326001034 10399
# - Accept:Expend           1  10746169 328097059 10404
# - Top10perc:S.F.Ratio     1  11457963 328808853 10406
# - Enroll:Room.Board       1  11980668 329331558 10407
# - Enroll:Outstate         1  13698781 331049671 10411
# - Accept:Top10perc        1  16156739 333507629 10417
# - Enroll:Books            1  17868578 335219468 10421
# - F.Undergrad:Books       1  18057310 335408200 10421
# - Accept:Room.Board       1  19255385 336606275 10424
# - Enroll:Expend           1  20290883 337641774 10426
# - Top10perc:Grad.Rate     1  24493224 341844114 10436
# - Accept:Top25perc        1  25004719 342355609 10437
# - Accept:Outstate         1  25574659 342925549 10438
#
# Step:  AIC=10382.43
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Terminal + Private:Grad.Rate + Accept:Top10perc +
#     Accept:Top25perc + Accept:F.Undergrad + Accept:Outstate +
#     Accept:Room.Board + Accept:Books + Accept:Expend + Accept:Grad.Rate +
#     Enroll:Top10perc + Enroll:Top25perc + Enroll:Outstate + Enroll:Room.Board +
#     Enroll:Books + Enroll:Personal + Enroll:Terminal + Enroll:Expend +
#     Enroll:Grad.Rate + Top10perc:F.Undergrad + Top10perc:S.F.Ratio +
#     Top10perc:perc.alumni + Top10perc:Grad.Rate + Top25perc:F.Undergrad +
#     Top25perc:S.F.Ratio + F.Undergrad:Outstate + F.Undergrad:Room.Board +
#     F.Undergrad:Books + F.Undergrad:Personal + P.Undergrad:Books +
#     P.Undergrad:Personal + Outstate:S.F.Ratio + Room.Board:S.F.Ratio +
#     perc.alumni:Expend
#
#                          Df Sum of Sq       RSS   AIC
# - Top25perc:F.Undergrad   1   2310723 321342776 10381
# - Private:Terminal        1   2354100 321386154 10382
# - F.Undergrad:Room.Board  1   2517853 321549906 10382
# - Room.Board:S.F.Ratio    1   2547088 321579142 10382
# <none>                                319032053 10382
# - F.Undergrad:Outstate    1   3329347 322361401 10384
# - Accept:Books            1   3758373 322790426 10385
# - P.Undergrad:Books       1   4686303 323718356 10387
# - Enroll:Top10perc        1   4701397 323733451 10387
# - Enroll:Personal         1   5579214 324611268 10389
# - Top10perc:perc.alumni   1   5740127 324772181 10390
# - Outstate:S.F.Ratio      1   5823410 324855463 10390
# - Top10perc:F.Undergrad   1   6201279 325233332 10391
# - Enroll:Terminal         1   6366584 325398638 10391
# - Enroll:Top25perc        1   6380305 325412358 10391
# - Accept:Grad.Rate        1   6550920 325582973 10392
# - perc.alumni:Expend      1   6674732 325706786 10392
# - P.Undergrad:Personal    1   7077788 326109841 10393
# - Enroll:Grad.Rate        1   7187691 326219744 10393
# - Accept:F.Undergrad      1   7903632 326935686 10395
# - Private:Grad.Rate       1   8605480 327637534 10396
# - F.Undergrad:Personal    1   8745790 327777843 10397
# - Accept:Expend           1   9283494 328315548 10398
# - Top25perc:S.F.Ratio     1   9456432 328488485 10398
# - Enroll:Room.Board       1  11405280 330437333 10403
# - Top10perc:S.F.Ratio     1  12921807 331953860 10407
# - Enroll:Outstate         1  13233789 332265842 10407
# - Accept:Top10perc        1  16741504 335773558 10416
# - Enroll:Books            1  17419461 336451514 10417
# - F.Undergrad:Books       1  17631311 336663365 10418
# - Enroll:Expend           1  19566748 338598801 10422
# - Accept:Room.Board       1  19657711 338689764 10422
# - Accept:Top25perc        1  24981386 344013440 10434
# - Accept:Outstate         1  26380393 345412446 10438
# - Top10perc:Grad.Rate     1  27655606 346687660 10440
#
# Step:  AIC=10381.39
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Terminal + Private:Grad.Rate + Accept:Top10perc +
#     Accept:Top25perc + Accept:F.Undergrad + Accept:Outstate +
#     Accept:Room.Board + Accept:Books + Accept:Expend + Accept:Grad.Rate +
#     Enroll:Top10perc + Enroll:Top25perc + Enroll:Outstate + Enroll:Room.Board +
#     Enroll:Books + Enroll:Personal + Enroll:Terminal + Enroll:Expend +
#     Enroll:Grad.Rate + Top10perc:F.Undergrad + Top10perc:S.F.Ratio +
#     Top10perc:perc.alumni + Top10perc:Grad.Rate + Top25perc:S.F.Ratio +
#     F.Undergrad:Outstate + F.Undergrad:Room.Board + F.Undergrad:Books +
#     F.Undergrad:Personal + P.Undergrad:Books + P.Undergrad:Personal +
#     Outstate:S.F.Ratio + Room.Board:S.F.Ratio + perc.alumni:Expend
#
#                          Df Sum of Sq       RSS   AIC
# - Room.Board:S.F.Ratio    1   2013899 323356675 10380
# - Private:Terminal        1   2177918 323520694 10380
# <none>                                321342776 10381
# - Accept:Books            1   3514894 324857671 10383
# - F.Undergrad:Room.Board  1   3539151 324881927 10383
# - P.Undergrad:Books       1   4557139 325899915 10386
# - Top10perc:F.Undergrad   1   4600572 325943349 10386
# - Enroll:Personal         1   4688557 326031333 10386
# - Outstate:S.F.Ratio      1   4911549 326254326 10386
# - F.Undergrad:Outstate    1   4997941 326340717 10387
# - Top10perc:perc.alumni   1   6533807 327876583 10390
# - Enroll:Terminal         1   6534762 327877538 10390
# - P.Undergrad:Personal    1   6896331 328239108 10391
# - perc.alumni:Expend      1   7133952 328476728 10392
# - F.Undergrad:Personal    1   7639552 328982329 10393
# - Accept:F.Undergrad      1   7715112 329057889 10393
# - Top25perc:S.F.Ratio     1   7911943 329254719 10394
# - Private:Grad.Rate       1   8119674 329462450 10394
# - Accept:Grad.Rate        1   8919688 330262464 10396
# - Accept:Expend           1   9012009 330354785 10396
# - Enroll:Grad.Rate        1   9590851 330933627 10398
# - Enroll:Top10perc        1  10982451 332325227 10401
# - Top10perc:S.F.Ratio     1  11383283 332726059 10402
# - Enroll:Room.Board       1  13299174 334641950 10406
# - Accept:Top10perc        1  14509048 335851824 10409
# - Enroll:Outstate         1  17817217 339159994 10417
# - Enroll:Top25perc        1  17936246 339279022 10417
# - Enroll:Books            1  18258787 339601563 10418
# - Enroll:Expend           1  18654771 339997548 10419
# - F.Undergrad:Books       1  19148981 340491758 10420
# - Accept:Room.Board       1  21039669 342382445 10424
# - Accept:Top25perc        1  22815770 344158546 10428
# - Top10perc:Grad.Rate     1  28499282 349842059 10441
# - Accept:Outstate         1  31298752 352641528 10447
#
# Step:  AIC=10379.58
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Terminal + Private:Grad.Rate + Accept:Top10perc +
#     Accept:Top25perc + Accept:F.Undergrad + Accept:Outstate +
#     Accept:Room.Board + Accept:Books + Accept:Expend + Accept:Grad.Rate +
#     Enroll:Top10perc + Enroll:Top25perc + Enroll:Outstate + Enroll:Room.Board +
#     Enroll:Books + Enroll:Personal + Enroll:Terminal + Enroll:Expend +
#     Enroll:Grad.Rate + Top10perc:F.Undergrad + Top10perc:S.F.Ratio +
#     Top10perc:perc.alumni + Top10perc:Grad.Rate + Top25perc:S.F.Ratio +
#     F.Undergrad:Outstate + F.Undergrad:Room.Board + F.Undergrad:Books +
#     F.Undergrad:Personal + P.Undergrad:Books + P.Undergrad:Personal +
#     Outstate:S.F.Ratio + perc.alumni:Expend
#
#                          Df Sum of Sq       RSS   AIC
# - Private:Terminal        1   2320527 325677202 10378
# <none>                                323356675 10380
# - Outstate:S.F.Ratio      1   2922148 326278824 10380
# - Accept:Books            1   3642263 326998939 10382
# - Top10perc:F.Undergrad   1   4275676 327632351 10383
# - P.Undergrad:Books       1   4335920 327692595 10383
# - Enroll:Personal         1   4554410 327911085 10384
# - F.Undergrad:Room.Board  1   4969067 328325742 10385
# - F.Undergrad:Outstate    1   5749059 329105734 10387
# - Enroll:Terminal         1   6347810 329704485 10388
# - Top10perc:perc.alumni   1   6348379 329705054 10388
# - P.Undergrad:Personal    1   6825353 330182028 10389
# - F.Undergrad:Personal    1   7359244 330715919 10390
# - Top25perc:S.F.Ratio     1   7954957 331311632 10392
# - Accept:F.Undergrad      1   7984770 331341445 10392
# - perc.alumni:Expend      1   8008016 331364691 10392
# - Private:Grad.Rate       1   8116167 331472842 10392
# - Accept:Expend           1   8917411 332274087 10394
# - Accept:Grad.Rate        1   9186391 332543066 10395
# - Enroll:Grad.Rate        1   9394201 332750877 10395
# - Enroll:Top10perc        1  11269477 334626153 10400
# - Top10perc:S.F.Ratio     1  11451077 334807752 10400
# - Enroll:Room.Board       1  14107844 337464520 10406
# - Accept:Top10perc        1  14308834 337665509 10407
# - Enroll:Top25perc        1  17816871 341173546 10415
# - Enroll:Expend           1  18013901 341370576 10415
# - Enroll:Outstate         1  18187715 341544390 10415
# - Enroll:Books            1  18257317 341613993 10416
# - F.Undergrad:Books       1  18761410 342118085 10417
# - Accept:Room.Board       1  20193456 343550131 10420
# - Accept:Top25perc        1  22656402 346013077 10426
# - Top10perc:Grad.Rate     1  27987229 351343904 10437
# - Accept:Outstate         1  30718039 354074714 10443
#
# Step:  AIC=10378.49
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Expend + Accept:Grad.Rate + Enroll:Top10perc +
#     Enroll:Top25perc + Enroll:Outstate + Enroll:Room.Board +
#     Enroll:Books + Enroll:Personal + Enroll:Terminal + Enroll:Expend +
#     Enroll:Grad.Rate + Top10perc:F.Undergrad + Top10perc:S.F.Ratio +
#     Top10perc:perc.alumni + Top10perc:Grad.Rate + Top25perc:S.F.Ratio +
#     F.Undergrad:Outstate + F.Undergrad:Room.Board + F.Undergrad:Books +
#     F.Undergrad:Personal + P.Undergrad:Books + P.Undergrad:Personal +
#     Outstate:S.F.Ratio + perc.alumni:Expend
#
#                          Df Sum of Sq       RSS   AIC
# - Outstate:S.F.Ratio      1   2601983 328279185 10378
# <none>                                325677202 10378
# - Accept:Books            1   3611066 329288268 10380
# - Top10perc:F.Undergrad   1   4163153 329840356 10382
# - Enroll:Terminal         1   4187390 329864592 10382
# - Enroll:Personal         1   4378969 330056171 10382
# - P.Undergrad:Books       1   4457398 330134601 10382
# - F.Undergrad:Room.Board  1   5041866 330719068 10384
# - F.Undergrad:Outstate    1   5865249 331542451 10386
# - Top10perc:perc.alumni   1   6095370 331772572 10386
# - P.Undergrad:Personal    1   6807598 332484801 10388
# - F.Undergrad:Personal    1   7040820 332718022 10388
# - perc.alumni:Expend      1   7755439 333432641 10390
# - Top25perc:S.F.Ratio     1   8486700 334163903 10392
# - Accept:Expend           1   8749736 334426939 10392
# - Private:Grad.Rate       1   9224436 334901638 10394
# - Accept:Grad.Rate        1   9680514 335357716 10395
# - Accept:F.Undergrad      1   9992602 335669805 10395
# - Enroll:Grad.Rate        1  10688506 336365708 10397
# - Top10perc:S.F.Ratio     1  11636810 337314012 10399
# - Enroll:Top10perc        1  11808720 337485922 10400
# - Enroll:Room.Board       1  14088318 339765520 10405
# - Accept:Top10perc        1  14524976 340202178 10406
# - Enroll:Books            1  17315759 342992962 10412
# - Enroll:Expend           1  17331710 343008912 10412
# - F.Undergrad:Books       1  17798971 343476173 10413
# - Enroll:Top25perc        1  18251759 343928961 10414
# - Enroll:Outstate         1  19012999 344690202 10416
# - Accept:Room.Board       1  19646334 345323536 10417
# - Accept:Top25perc        1  22798358 348475560 10424
# - Top10perc:Grad.Rate     1  27500298 353177501 10435
# - Accept:Outstate         1  32324581 358001783 10445
#
# Step:  AIC=10378.01
# Apps ~ Private + Accept + Enroll + Top10perc + Top25perc + F.Undergrad +
#     P.Undergrad + Outstate + Room.Board + Books + Personal +
#     Terminal + S.F.Ratio + perc.alumni + Expend + Grad.Rate +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Expend + Accept:Grad.Rate + Enroll:Top10perc +
#     Enroll:Top25perc + Enroll:Outstate + Enroll:Room.Board +
#     Enroll:Books + Enroll:Personal + Enroll:Terminal + Enroll:Expend +
#     Enroll:Grad.Rate + Top10perc:F.Undergrad + Top10perc:S.F.Ratio +
#     Top10perc:perc.alumni + Top10perc:Grad.Rate + Top25perc:S.F.Ratio +
#     F.Undergrad:Outstate + F.Undergrad:Room.Board + F.Undergrad:Books +
#     F.Undergrad:Personal + P.Undergrad:Books + P.Undergrad:Personal +
#     perc.alumni:Expend
#
#                          Df Sum of Sq       RSS   AIC
# <none>                                328279185 10378
# - Accept:Books            1   3943304 332222489 10381
# - P.Undergrad:Books       1   4286732 332565918 10381
# - Top10perc:F.Undergrad   1   4331255 332610440 10382
# - Enroll:Personal         1   4386758 332665943 10382
# - Enroll:Terminal         1   4535851 332815036 10382
# - F.Undergrad:Room.Board  1   4956083 333235268 10383
# - P.Undergrad:Personal    1   6433333 334712519 10386
# - F.Undergrad:Outstate    1   6613710 334892896 10387
# - Top10perc:perc.alumni   1   6741399 335020584 10387
# - F.Undergrad:Personal    1   6899546 335178731 10388
# - Accept:Expend           1   7471588 335750773 10389
# - Top25perc:S.F.Ratio     1   8934008 337213193 10392
# - Private:Grad.Rate       1   9055378 337334563 10392
# - Accept:Grad.Rate        1   9278229 337557414 10393
# - Accept:F.Undergrad      1   9472556 337751741 10394
# - perc.alumni:Expend      1   9917322 338196507 10394
# - Enroll:Grad.Rate        1  10232474 338511659 10395
# - Enroll:Top10perc        1  12988210 341267395 10402
# - Enroll:Room.Board       1  13573426 341852611 10403
# - Enroll:Expend           1  15316434 343595619 10407
# - Accept:Top10perc        1  15677242 343956428 10408
# - Top10perc:S.F.Ratio     1  16907049 345186235 10410
# - Enroll:Books            1  18346263 346625448 10414
# - F.Undergrad:Books       1  18749574 347028760 10414
# - Enroll:Outstate         1  18786398 347065583 10415
# - Accept:Room.Board       1  19349455 347628640 10416
# - Enroll:Top25perc        1  20411798 348690984 10418
# - Accept:Top25perc        1  24992538 353271723 10428
# - Top10perc:Grad.Rate     1  28240709 356519894 10436
# - Accept:Outstate         1  30674645 358953830 10441

# %%
#r2_adj
summary(lm_simple)$adj.r.squared        #0.927
summary(lm_2)$adj.r.squared             #0.970
summary(lm_2_stepAIC)$adj.r.squared     #0.972
summary(lm_2_stepBIC)$adj.r.squared     #0.969

#no predictores
length(lm_simple$coefficients)-1         #17
length(lm_2$coefficients)-1              #153
length(lm_2_stepAIC$coefficients)-1      #87
length(lm_2_stepBIC$coefficients)-1      #46
# Out:
# [1] 0.9276027
# [1] 0.9707533
# [1] 0.9726046
# [1] 0.9699771
# [1] 17
# [1] 153
# [1] 87
# [1] 46

# %%
#errores aparentes ECM
ecm_lm <- function(model){
  return(mean(model$residuals^2))
}
ecm_lm(lm_simple)                       #1059279
ecm_lm(lm_2)                            #351245.2 #best
ecm_lm(lm_2_stepAIC)                    #363867.4
ecm_lm(lm_2_stepBIC)                    #422495.7
# Out:
# [1] 1059279
# [1] 351245.2
# [1] 363867.4
# [1] 422495.7

# %%
# Errores de prueba
# función que calcula el error de prueba con B = 1
ECM_test <- function(model, ntrain){ #ntrain = número de elementos de la muestra de entrenamiento
  train <- sample(1:n, ntrain)
  p <- predict(lm(model$call$formula, College[train,]), newdata = College[-train,])
  return(mean((p - College[-train, "Apps"])^2))
}
# función que calcula el error de prueba B-veces
ECM_test_B <- function(model, B, ntrain){
  return(replicate(B, ECM_test(model, ntrain)))
}

# %%
t0 = proc.time()
set.seed(11)  #1297676
mean(ECM_test_B(model = lm_simple, B = 2000, ntrain = round(0.75*n))) 

set.seed(11)  #2043517
mean(ECM_test_B(model = lm_2, B = 2000, ntrain = round(0.75*n)))

set.seed(11)  #970122.7
mean(ECM_test_B(model = lm_2_stepAIC, B = 2000, ntrain = round(0.75*n)))

set.seed(11)  #793949.2 #best
mean(ECM_test_B(model = lm_2_stepBIC, B = 2000, ntrain = round(0.75*n)))
proc.time() - t0  
# user  system elapsed  
#85.44    0.69   86.64   acer intel i5 (12 GB ram)
#60.891   0.112  61.110  Google Colab (Some power)
# Out:
# [1] 1297676
# [1] 2043517
# [1] 970122.7
# [1] 793949.2
#    user  system elapsed
#  60.247   0.241  60.621

# %%
lm_2_stepAIC$call
# Out:
# lm(formula = Apps ~ Private + Accept + Enroll + Top10perc + Top25perc +
#     F.Undergrad + P.Undergrad + Outstate + Room.Board + Books +
#     Personal + PhD + Terminal + S.F.Ratio + perc.alumni + Expend +
#     Grad.Rate + Private:Terminal + Private:S.F.Ratio + Private:Expend +
#     Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Personal + Accept:S.F.Ratio + Accept:Expend +
#     Accept:Grad.Rate + Enroll:Top10perc + Enroll:Top25perc +
#     Enroll:F.Undergrad + Enroll:P.Undergrad + Enroll:Outstate +
#     Enroll:Room.Board + Enroll:Books + Enroll:Personal + Enroll:PhD +
#     Enroll:Terminal + Enroll:Expend + Enroll:Grad.Rate + Top10perc:Top25perc +
#     Top10perc:F.Undergrad + Top10perc:Outstate + Top10perc:Books +
#     Top10perc:Personal + Top10perc:PhD + Top10perc:Terminal +
#     Top10perc:S.F.Ratio + Top10perc:perc.alumni + Top10perc:Expend +
#     Top10perc:Grad.Rate + Top25perc:F.Undergrad + Top25perc:Outstate +
#     Top25perc:Books + Top25perc:Personal + Top25perc:S.F.Ratio +
#     F.Undergrad:P.Undergrad + F.Undergrad:Outstate + F.Undergrad:Room.Board +
#     F.Undergrad:Books + F.Undergrad:Personal + F.Undergrad:PhD +
#     F.Undergrad:Terminal + F.Undergrad:Grad.Rate + P.Undergrad:Books +
#     P.Undergrad:Personal + P.Undergrad:Terminal + P.Undergrad:S.F.Ratio +
#     P.Undergrad:perc.alumni + P.Undergrad:Expend + Outstate:PhD +
#     Outstate:S.F.Ratio + Room.Board:Personal + Room.Board:Terminal +
#     Room.Board:S.F.Ratio + Room.Board:Expend + Books:Personal +
#     Books:PhD + Books:Terminal + Books:Expend + Books:Grad.Rate +
#     Personal:Expend + Personal:Grad.Rate + perc.alumni:Expend,
#     data = College)

# %%
lm_2_stepBIC
# Out:
# Call:
# lm(formula = Apps ~ Private + Accept + Enroll + Top10perc + Top25perc +
#     F.Undergrad + P.Undergrad + Outstate + Room.Board + Books +
#     Personal + Terminal + S.F.Ratio + perc.alumni + Expend +
#     Grad.Rate + Private:Grad.Rate + Accept:Top10perc + Accept:Top25perc +
#     Accept:F.Undergrad + Accept:Outstate + Accept:Room.Board +
#     Accept:Books + Accept:Expend + Accept:Grad.Rate + Enroll:Top10perc +
#     Enroll:Top25perc + Enroll:Outstate + Enroll:Room.Board +
#     Enroll:Books + Enroll:Personal + Enroll:Terminal + Enroll:Expend +
#     Enroll:Grad.Rate + Top10perc:F.Undergrad + Top10perc:S.F.Ratio +
#     Top10perc:perc.alumni + Top10perc:Grad.Rate + Top25perc:S.F.Ratio +
#     F.Undergrad:Outstate + F.Undergrad:Room.Board + F.Undergrad:Books +
#     F.Undergrad:Personal + P.Undergrad:Books + P.Undergrad:Personal +
#     perc.alumni:Expend, data = College)
#
# Coefficients:
#            (Intercept)              PrivateYes                  Accept
#              1.190e+03               1.072e+03               6.455e-01
#                 Enroll               Top10perc               Top25perc
#             -7.071e-01               1.559e+01              -4.389e+01
#            F.Undergrad             P.Undergrad                Outstate
#              5.205e-01              -7.865e-02               9.990e-03
#             Room.Board                   Books                Personal
#              7.281e-03              -4.516e-01               3.933e-02
#               Terminal               S.F.Ratio             perc.alumni
#              5.536e+00              -4.616e+01              -1.094e+01
#                 Expend               Grad.Rate    PrivateYes:Grad.Rate
#             -1.128e-01              -4.759e-02              -2.255e+01
#       Accept:Top10perc        Accept:Top25perc      Accept:F.Undergrad
#             -2.110e-02               2.173e-02              -8.168e-06
#        Accept:Outstate       Accept:Room.Board            Accept:Books
#             -1.022e-04               2.929e-04              -7.068e-04
#          Accept:Expend        Accept:Grad.Rate        Enroll:Top10perc
#             -3.419e-05               9.689e-03               5.736e-02
#       Enroll:Top25perc         Enroll:Outstate       Enroll:Room.Board
#             -5.125e-02               4.347e-04              -1.186e-03
#           Enroll:Books         Enroll:Personal         Enroll:Terminal
#              8.979e-03              -5.424e-04              -1.392e-02
#          Enroll:Expend        Enroll:Grad.Rate   Top10perc:F.Undergrad
#              1.428e-04              -2.736e-02               4.174e-03
#    Top10perc:S.F.Ratio   Top10perc:perc.alumni     Top10perc:Grad.Rate
#             -5.664e+00              -6.711e-01               1.016e+00
#    Top25perc:S.F.Ratio    F.Undergrad:Outstate  F.Undergrad:Room.Board
#              3.544e+00              -4.245e-05               1.052e-04
#      F.Undergrad:Books    F.Undergrad:Personal       P.Undergrad:Books
#             -1.510e-03               1.347e-04               6.368e-04
#   P.Undergrad:Personal      perc.alumni:Expend
#             -1.244e-04               2.880e-03

# %% [markdown]
# ## RIDGE REGRESSION

# %%
x <- model.matrix(Apps~.^2, College)[, -1] #input matrix, of dimension nobs x nvars
y <- College$Apps #response variable

# %%
# trabajaremos con el modelo step(lm ~ .^2, k=log(n))
ridgemod <- glmnet(x, y, alpha = 0) #esto solo es para conseguir los valores de lambda
val_lambda <- ridgemod$lambda

# %%
#función para calcular error de prueba para un valor de lambda UNA SOLA VEZ
ntrain <- round(0.75*n)
test_lambda_RR <- function(lambda){
  train <- sample(1:n, ntrain)
  ridge_mod <- glmnet(x[train,], y[train], alpha = 0)
  ridge_pred <- predict(ridge_mod, s = lambda, newx = x[-train, ])
  return(mean((ridge_pred - y[-train])^2))
}
#función para calcular error de prueba para valores de lambda UNA SOLA VEZ
test_lambda_RR_VEC <- Vectorize(test_lambda_RR)
#función para calcular error de prueba para valores de lambda B-VECES
test_lambda_RR_B <- function(lambda, B){
  return(replicate(B, test_lambda_RR_VEC(lambda)))
}

# %%
set.seed(11)
t0 <- proc.time()
lamdas_test <- test_lambda_RR_B(lambda = val_lambda, B = 1000)
proc.time() - t0 
#    user   system  elapsed  Google colab (Many power)
#3003.269    4.894 3013.140
# Out:
#     user   system  elapsed
# 2992.559    5.560 3002.451

# %%
mean_test_lambda_RR <- apply(lamdas_test, 1, mean)
wmin_RR <- which.min(mean_test_lambda_RR)
print(min(mean_test_lambda_RR)) #1124391
print(val_lambda[wmin_RR])      #366.6069
# Out:
# [1] 1124391
# [1] 366.6069

# %%
set.seed(11)
RR_2000_sim <- test_lambda_RR_B(val_lambda[wmin_RR], 2000) #1111670.09960162
mean(RR_2000_sim)
# Out:
# [1] 1111670

# %%
#error aparente RIDGE REGRESSION 
#659201.2
ridge_mod_ap <- glmnet(x, y, alpha = 0)
ridge_pred_ap <- predict(ridge_mod_ap, s = val_lambda[wmin_RR], newx = x)
print(mean((ridge_pred_ap - y)^2))
# Out:
# [1] 659201.2

# %%
out <- glmnet (x, y, alpha = 0)
rr_coef <-  predict(out , type = "coefficients", s = val_lambda[wmin_RR])
print(length(rr_coef))
# Out:
# [1] 154

# %%
rr_coef
# Out:
# 154 x 1 sparse Matrix of class "dgCMatrix"
#                                    s1
# (Intercept)              7.399189e+02
# PrivateYes              -3.361939e+01
# Accept                   1.416624e-01
# Enroll                  -4.671362e-02
# Top10perc               -2.722976e+00
# Top25perc               -1.255925e+00
# F.Undergrad              3.481561e-04
# P.Undergrad              1.626770e-02
# Outstate                -7.835606e-03
# Room.Board               6.552195e-03
# Books                    1.178109e-01
# Personal                -4.036138e-02
# PhD                      6.046222e-01
# Terminal                 1.076872e+00
# S.F.Ratio                4.705819e+00
# perc.alumni             -4.630202e+00
# Expend                  -1.537414e-02
# Grad.Rate               -2.516044e+00
# PrivateYes:Accept       -1.167334e-01
# PrivateYes:Enroll        3.862526e-01
# PrivateYes:Top10perc    -8.567876e-01
# PrivateYes:Top25perc    -4.141297e+00
# PrivateYes:F.Undergrad   1.459879e-02
# PrivateYes:P.Undergrad  -6.956092e-03
# PrivateYes:Outstate     -6.716500e-04
# PrivateYes:Room.Board   -3.050107e-02
# PrivateYes:Books         1.301497e-01
# PrivateYes:Personal      6.478306e-02
# PrivateYes:PhD          -7.906857e-01
# PrivateYes:Terminal     -1.668630e+00
# PrivateYes:S.F.Ratio     6.278402e+00
# PrivateYes:perc.alumni  -1.390022e-01
# PrivateYes:Expend       -1.124235e-02
# PrivateYes:Grad.Rate    -3.492946e+00
# Accept:Enroll           -2.361635e-06
# Accept:Top10perc         1.164871e-03
# Accept:Top25perc         1.977382e-03
# Accept:F.Undergrad       1.413838e-06
# Accept:P.Undergrad       2.697183e-05
# Accept:Outstate         -6.958272e-07
# Accept:Room.Board        2.890681e-05
# Accept:Books             2.138436e-04
# Accept:Personal          7.157215e-05
# Accept:PhD               1.258353e-03
# Accept:Terminal          1.357048e-03
# Accept:S.F.Ratio         1.026939e-02
# Accept:perc.alumni       4.029473e-03
# Accept:Expend            4.673907e-07
# Accept:Grad.Rate         2.409301e-03
# Enroll:Top10perc         3.522989e-03
# Enroll:Top25perc         4.943685e-04
# Enroll:F.Undergrad      -1.953862e-05
# Enroll:P.Undergrad      -1.481674e-05
# Enroll:Outstate         -5.738273e-08
# Enroll:Room.Board        4.274260e-06
# Enroll:Books            -9.886356e-05
# Enroll:Personal         -3.362645e-05
# Enroll:PhD              -9.609666e-04
# Enroll:Terminal         -6.321528e-04
# Enroll:S.F.Ratio        -9.157723e-03
# Enroll:perc.alumni      -3.729509e-04
# Enroll:Expend            1.558272e-05
# Enroll:Grad.Rate         1.197584e-03
# Top10perc:Top25perc      6.749357e-02
# Top10perc:F.Undergrad    8.029988e-04
# Top10perc:P.Undergrad   -1.776915e-03
# Top10perc:Outstate       3.445107e-04
# Top10perc:Room.Board     7.064922e-04
# Top10perc:Books          1.748466e-05
# Top10perc:Personal       5.741811e-04
# Top10perc:PhD           -1.348633e-02
# Top10perc:Terminal      -8.608831e-03
# Top10perc:S.F.Ratio     -1.126954e+00
# Top10perc:perc.alumni    1.344367e-01
# Top10perc:Expend         4.841332e-04
# Top10perc:Grad.Rate      1.439235e-01
# Top25perc:F.Undergrad    2.239347e-04
# Top25perc:P.Undergrad    1.502213e-04
# Top25perc:Outstate      -1.136175e-04
# Top25perc:Room.Board     1.070392e-04
# Top25perc:Books          2.767477e-04
# Top25perc:Personal      -2.177888e-04
# Top25perc:PhD           -2.173401e-02
# Top25perc:Terminal      -1.174289e-02
# Top25perc:S.F.Ratio      5.383559e-02
# Top25perc:perc.alumni   -5.277964e-02
# Top25perc:Expend         4.592983e-06
# Top25perc:Grad.Rate      5.667369e-02
# F.Undergrad:P.Undergrad -2.739301e-06
# F.Undergrad:Outstate     6.942521e-07
# F.Undergrad:Room.Board   2.710083e-06
# F.Undergrad:Books       -1.903165e-05
# F.Undergrad:Personal    -3.028706e-07
# F.Undergrad:PhD         -8.375241e-05
# F.Undergrad:Terminal     7.595820e-06
# F.Undergrad:S.F.Ratio   -6.188136e-04
# F.Undergrad:perc.alumni -2.134857e-04
# F.Undergrad:Expend       2.924476e-06
# F.Undergrad:Grad.Rate    3.819352e-04
# P.Undergrad:Outstate    -2.004381e-06
# P.Undergrad:Room.Board   4.995292e-09
# P.Undergrad:Books        4.303855e-05
# P.Undergrad:Personal    -2.188707e-07
# P.Undergrad:PhD          1.299654e-04
# P.Undergrad:Terminal     2.483264e-04
# P.Undergrad:S.F.Ratio    2.495820e-03
# P.Undergrad:perc.alumni -2.863343e-04
# P.Undergrad:Expend      -1.293340e-06
# P.Undergrad:Grad.Rate   -3.416399e-04
# Outstate:Room.Board     -8.317436e-07
# Outstate:Books          -2.142423e-06
# Outstate:Personal        3.162094e-06
# Outstate:PhD            -7.019213e-05
# Outstate:Terminal       -1.058402e-04
# Outstate:S.F.Ratio      -1.533123e-03
# Outstate:perc.alumni     3.521280e-04
# Outstate:Expend          2.339832e-07
# Outstate:Grad.Rate       5.455881e-05
# Room.Board:Books         2.153592e-05
# Room.Board:Personal      4.148854e-06
# Room.Board:PhD           4.822591e-05
# Room.Board:Terminal      3.023153e-06
# Room.Board:S.F.Ratio     2.955501e-03
# Room.Board:perc.alumni   9.973966e-05
# Room.Board:Expend        2.877434e-08
# Room.Board:Grad.Rate     1.767871e-04
# Books:Personal          -2.024684e-04
# Books:PhD               -1.073912e-03
# Books:Terminal           1.348490e-05
# Books:S.F.Ratio          1.674251e-03
# Books:perc.alumni       -2.207991e-03
# Books:Expend            -2.210073e-05
# Books:Grad.Rate          6.522775e-04
# Personal:PhD            -7.124728e-04
# Personal:Terminal       -7.050105e-04
# Personal:S.F.Ratio       2.936692e-03
# Personal:perc.alumni     2.279324e-03
# Personal:Expend          5.605571e-07
# Personal:Grad.Rate       6.001978e-05
# PhD:Terminal            -1.516463e-02
# PhD:S.F.Ratio            7.773729e-02
# PhD:perc.alumni         -4.033459e-02
# PhD:Expend              -8.119155e-05
# PhD:Grad.Rate            2.254776e-02
# Terminal:S.F.Ratio       1.787962e-01
# Terminal:perc.alumni    -4.973729e-02
# Terminal:Expend         -1.310491e-04
# Terminal:Grad.Rate       2.130005e-02
# S.F.Ratio:perc.alumni   -4.844225e-01
# S.F.Ratio:Expend         1.425477e-03
# S.F.Ratio:Grad.Rate     -2.193312e-01
# perc.alumni:Expend       5.864330e-04
# perc.alumni:Grad.Rate    1.925740e-02
# Expend:Grad.Rate         1.537099e-04

# %% [markdown]
# ## LASSO

# %%
lassomod <- glmnet(x, y, alpha = 1) #esto solo es para conseguir los valores de lambda
val_lambda_lasso <- lassomod$lambda

# %%
#función para calcular error de prueba para un valor de lambda UNA SOLA VEZ
ntrain <- round(0.75*n)
test_lambda_lasso <- function(lambda){
  train <- sample(1:n, ntrain)
  lasso_mod <- glmnet(x[train,], y[train], alpha = 1)
  lasso_pred <- predict(lasso_mod, s = lambda, newx = x[-train, ])
  return(mean((lasso_pred - y[-train])^2))
}
#función para calcular error de prueba para valores de lambda UNA SOLA VEZ
test_lambda_lasso_VEC <- Vectorize(test_lambda_lasso)
#función para calcular error de prueba para valores de lambda B-VECES
test_lambda_lasso_B <- function(lambda, B){
  return(replicate(B, test_lambda_lasso_VEC(lambda)))
}

# %%
set.seed(11)
t0 <- proc.time()
lambdas_test_lasso <- test_lambda_lasso_B(lambda = val_lambda_lasso, B = 1000)
proc.time() - t0 
#     user   system  elapsed 
# 9739.428    6.505 9758.199 ~162min
# Out:
#     user   system  elapsed
# 9739.428    6.505 9758.199

# %%
mean_test_lambda_lasso <- apply(lambdas_test_lasso, 1, mean)
wmin_lasso <- which.min(mean_test_lambda_lasso)
print(min(mean_test_lambda_lasso)) #1083800
print(val_lambda_lasso[wmin_lasso]) #20.02509
# Out:
# [1] 997030.8
# [1] 9.513538

# %%
set.seed(11)
lasso_2000_sim <- test_lambda_lasso_B(val_lambda_lasso[wmin_lasso], 2000)
mean(lasso_2000_sim) #1012865.37094287
# Out:
# [1] 1012865

# %%
out <- glmnet (x, y, alpha = 1)
lasso_coef <-  predict(out , type = "coefficients", s = val_lambda_lasso[wmin_lasso])
print(length(lasso_coef))
# Out:
# [1] 154

# %%
print(length(lasso_coef[lasso_coef != 0 ]))
lasso_coef
# Out:
# <sparse>[ <logic> ] : .M.sub.i.logical() maybe inefficient
# [1] 41
# 154 x 1 sparse Matrix of class "dgCMatrix"
#                                    s1
# (Intercept)              8.178761e+02
# PrivateYes               .
# Accept                   2.657987e-01
# Enroll                   .
# Top10perc                .
# Top25perc                .
# F.Undergrad              .
# P.Undergrad              .
# Outstate                 .
# Room.Board               .
# Books                    .
# Personal                 .
# PhD                      .
# Terminal                 .
# S.F.Ratio                .
# perc.alumni             -6.494561e+00
# Expend                  -3.437825e-03
# Grad.Rate               -9.147170e+00
# PrivateYes:Accept       -2.299159e-01
# PrivateYes:Enroll        7.065327e-01
# PrivateYes:Top10perc     .
# PrivateYes:Top25perc    -5.018338e+00
# PrivateYes:F.Undergrad   .
# PrivateYes:P.Undergrad   1.205121e-03
# PrivateYes:Outstate      .
# PrivateYes:Room.Board    .
# PrivateYes:Books         .
# PrivateYes:Personal      .
# PrivateYes:PhD           .
# PrivateYes:Terminal      .
# PrivateYes:S.F.Ratio     .
# PrivateYes:perc.alumni   .
# PrivateYes:Expend        .
# PrivateYes:Grad.Rate    -3.751868e+00
# Accept:Enroll            .
# Accept:Top10perc         .
# Accept:Top25perc         2.963766e-03
# Accept:F.Undergrad       .
# Accept:P.Undergrad       2.455023e-05
# Accept:Outstate         -7.724388e-06
# Accept:Room.Board        2.861981e-05
# Accept:Books             1.181521e-06
# Accept:Personal          3.980871e-05
# Accept:PhD               .
# Accept:Terminal          .
# Accept:S.F.Ratio         3.128439e-02
# Accept:perc.alumni       .
# Accept:Expend           -3.598601e-06
# Accept:Grad.Rate         5.302607e-03
# Enroll:Top10perc         1.146386e-03
# Enroll:Top25perc         .
# Enroll:F.Undergrad      -3.799635e-05
# Enroll:P.Undergrad       .
# Enroll:Outstate          .
# Enroll:Room.Board        .
# Enroll:Books             .
# Enroll:Personal          .
# Enroll:PhD               .
# Enroll:Terminal          .
# Enroll:S.F.Ratio        -3.636305e-02
# Enroll:perc.alumni       .
# Enroll:Expend            4.954724e-05
# Enroll:Grad.Rate         .
# Top10perc:Top25perc      .
# Top10perc:F.Undergrad    3.080652e-03
# Top10perc:P.Undergrad   -1.500391e-03
# Top10perc:Outstate       .
# Top10perc:Room.Board     .
# Top10perc:Books          .
# Top10perc:Personal       .
# Top10perc:PhD            .
# Top10perc:Terminal       .
# Top10perc:S.F.Ratio     -2.756975e+00
# Top10perc:perc.alumni    .
# Top10perc:Expend         1.879881e-04
# Top10perc:Grad.Rate      5.296285e-01
# Top25perc:F.Undergrad    .
# Top25perc:P.Undergrad    .
# Top25perc:Outstate       .
# Top25perc:Room.Board     .
# Top25perc:Books          .
# Top25perc:Personal       .
# Top25perc:PhD            .
# Top25perc:Terminal       .
# Top25perc:S.F.Ratio      2.636087e-01
# Top25perc:perc.alumni    .
# Top25perc:Expend         .
# Top25perc:Grad.Rate      .
# F.Undergrad:P.Undergrad  .
# F.Undergrad:Outstate     .
# F.Undergrad:Room.Board   .
# F.Undergrad:Books        .
# F.Undergrad:Personal     .
# F.Undergrad:PhD          .
# F.Undergrad:Terminal     .
# F.Undergrad:S.F.Ratio    .
# F.Undergrad:perc.alumni  .
# F.Undergrad:Expend       1.545249e-06
# F.Undergrad:Grad.Rate    .
# P.Undergrad:Outstate     .
# P.Undergrad:Room.Board   .
# P.Undergrad:Books        .
# P.Undergrad:Personal     .
# P.Undergrad:PhD          .
# P.Undergrad:Terminal     .
# P.Undergrad:S.F.Ratio    1.172234e-03
# P.Undergrad:perc.alumni  .
# P.Undergrad:Expend       .
# P.Undergrad:Grad.Rate    .
# Outstate:Room.Board      .
# Outstate:Books           .
# Outstate:Personal        .
# Outstate:PhD             .
# Outstate:Terminal        .
# Outstate:S.F.Ratio      -3.518297e-04
# Outstate:perc.alumni     .
# Outstate:Expend          .
# Outstate:Grad.Rate       .
# Room.Board:Books         .
# Room.Board:Personal      .
# Room.Board:PhD           .
# Room.Board:Terminal      .
# Room.Board:S.F.Ratio     3.538262e-03
# Room.Board:perc.alumni   .
# Room.Board:Expend        .
# Room.Board:Grad.Rate     .
# Books:Personal          -8.935743e-05
# Books:PhD                .
# Books:Terminal           .
# Books:S.F.Ratio          1.810360e-02
# Books:perc.alumni        .
# Books:Expend            -2.615595e-06
# Books:Grad.Rate          .
# Personal:PhD             .
# Personal:Terminal        .
# Personal:S.F.Ratio       .
# Personal:perc.alumni     .
# Personal:Expend          .
# Personal:Grad.Rate       .
# PhD:Terminal             .
# PhD:S.F.Ratio            .
# PhD:perc.alumni         -3.068752e-03
# PhD:Expend               .
# PhD:Grad.Rate            .
# Terminal:S.F.Ratio       6.261580e-02
# Terminal:perc.alumni    -6.299440e-03
# Terminal:Expend         -3.805963e-04
# Terminal:Grad.Rate       .
# S.F.Ratio:perc.alumni    .
# S.F.Ratio:Expend         .
# S.F.Ratio:Grad.Rate      .
# perc.alumni:Expend       7.250710e-04
# perc.alumni:Grad.Rate    .
# Expend:Grad.Rate         .

# %%
#error aparente LASSO
#563410.9
lasso_mod_ap <- glmnet(x, y, alpha = 1)
lasso_pred_ap <- predict(lasso_mod_ap, s = val_lambda_lasso[wmin_lasso], newx = x)
print(mean((lasso_pred_ap - y)^2))
# Out:
# [1] 563410.9

# %% [markdown]
# ## Elastic

# %%
elasticmod <- glmnet(x, y, alpha = 0.5) #esto solo es para conseguir los valores de lambda
val_lambda_elastic <- elasticmod$lambda

# %%
#función para calcular error de prueba para un valor de lambda UNA SOLA VEZ
ntrain <- round(0.75*n)
test_lambda_elastic <- function(lambda){
  train <- sample(1:n, ntrain)
  elastic_mod <- glmnet(x[train,], y[train], alpha = 0.5)
  elastic_pred <- predict(elastic_mod, s = lambda, newx = x[-train, ])
  return(mean((elastic_pred - y[-train])^2))
}
#función para calcular error de prueba para valores de lambda UNA SOLA VEZ
test_lambda_elastic_VEC <- Vectorize(test_lambda_elastic)
#función para calcular error de prueba para valores de lambda B-VECES
test_lambda_elastic_B <- function(lambda, B){
  return(replicate(B, test_lambda_elastic_VEC(lambda)))
}

# %%
set.seed(11)
t0 <- proc.time()
lambdas_test_elastic <- test_lambda_elastic_B(lambda = val_lambda_elastic, B = 1000)
proc.time() - t0 
#     user   system  elapsed ~147min
# 8843.743    6.373 8861.584
# Out:
#     user   system  elapsed
# 8843.743    6.373 8861.584

# %%
mean_test_lambda_elastic <- apply(lambdas_test_elastic, 1, mean)
wmin_elastic <- which.min(mean_test_lambda_elastic)
print(min(mean_test_lambda_elastic)) #1083800
print(val_lambda_elastic[wmin_elastic]) #20.02509
# Out:
# [1] 983074.4
# [1] 11.94956

# %%
# 2000 reps error de prueba
elastic_2000_sim <- test_lambda_elastic_B(val_lambda_elastic[wmin_elastic], 2000)
mean(elastic_2000_sim)
# Out:
# [1] 992524.4

# %%
#error aparente elastic
#591628
elastic_mod_ap <- glmnet(x, y, alpha = 1)
elastic_pred_ap <- predict(elastic_mod_ap, s = val_lambda_elastic[wmin_elastic], newx = x)
print(mean((elastic_pred_ap - y)^2))
# Out:
# [1] 591628

# %%
#coeicientes
out <- glmnet (x, y, alpha = 0.5)
elastic_coef <-  predict(out , type = "coefficients", s = val_lambda_elastic[wmin_elastic])
print(length(elastic_coef))
# Out:
# [1] 154

# %%
elastic_coef
# Out:
# 154 x 1 sparse Matrix of class "dgCMatrix"
#                                    s1
# (Intercept)              8.597364e+02
# PrivateYes               .
# Accept                   3.259856e-01
# Enroll                   .
# Top10perc                .
# Top25perc                .
# F.Undergrad              .
# P.Undergrad              .
# Outstate                 .
# Room.Board               .
# Books                    .
# Personal                 .
# PhD                      .
# Terminal                 .
# S.F.Ratio                .
# perc.alumni             -7.469503e+00
# Expend                  -3.078142e-02
# Grad.Rate               -6.743382e+00
# PrivateYes:Accept       -2.257389e-01
# PrivateYes:Enroll        6.944543e-01
# PrivateYes:Top10perc     .
# PrivateYes:Top25perc    -5.349999e+00
# PrivateYes:F.Undergrad   .
# PrivateYes:P.Undergrad   4.579085e-03
# PrivateYes:Outstate      .
# PrivateYes:Room.Board    .
# PrivateYes:Books         .
# PrivateYes:Personal      3.860128e-02
# PrivateYes:PhD           .
# PrivateYes:Terminal      .
# PrivateYes:S.F.Ratio     .
# PrivateYes:perc.alumni   .
# PrivateYes:Expend        .
# PrivateYes:Grad.Rate    -3.525380e+00
# Accept:Enroll            .
# Accept:Top10perc        -1.105549e-03
# Accept:Top25perc         3.444413e-03
# Accept:F.Undergrad       .
# Accept:P.Undergrad       2.486459e-05
# Accept:Outstate         -1.000831e-05
# Accept:Room.Board        3.099271e-05
# Accept:Books             1.802461e-05
# Accept:Personal          4.879155e-05
# Accept:PhD               .
# Accept:Terminal          .
# Accept:S.F.Ratio         2.934504e-02
# Accept:perc.alumni       .
# Accept:Expend           -7.186521e-06
# Accept:Grad.Rate         5.451435e-03
# Enroll:Top10perc         3.852250e-03
# Enroll:Top25perc         .
# Enroll:F.Undergrad      -3.930698e-05
# Enroll:P.Undergrad       .
# Enroll:Outstate          .
# Enroll:Room.Board        .
# Enroll:Books             .
# Enroll:Personal          .
# Enroll:PhD               .
# Enroll:Terminal          .
# Enroll:S.F.Ratio        -4.345451e-02
# Enroll:perc.alumni       .
# Enroll:Expend            5.102597e-05
# Enroll:Grad.Rate         .
# Top10perc:Top25perc      .
# Top10perc:F.Undergrad    2.962063e-03
# Top10perc:P.Undergrad   -1.957280e-03
# Top10perc:Outstate       2.128374e-07
# Top10perc:Room.Board     .
# Top10perc:Books          .
# Top10perc:Personal       .
# Top10perc:PhD            .
# Top10perc:Terminal       .
# Top10perc:S.F.Ratio     -2.934677e+00
# Top10perc:perc.alumni    .
# Top10perc:Expend         3.827145e-04
# Top10perc:Grad.Rate      5.286495e-01
# Top25perc:F.Undergrad    .
# Top25perc:P.Undergrad    .
# Top25perc:Outstate       .
# Top25perc:Room.Board     .
# Top25perc:Books          .
# Top25perc:Personal       .
# Top25perc:PhD           -2.242510e-02
# Top25perc:Terminal       .
# Top25perc:S.F.Ratio      4.596291e-01
# Top25perc:perc.alumni   -2.866819e-02
# Top25perc:Expend         .
# Top25perc:Grad.Rate      .
# F.Undergrad:P.Undergrad  .
# F.Undergrad:Outstate     .
# F.Undergrad:Room.Board   .
# F.Undergrad:Books        .
# F.Undergrad:Personal     .
# F.Undergrad:PhD          .
# F.Undergrad:Terminal     .
# F.Undergrad:S.F.Ratio    .
# F.Undergrad:perc.alumni  .
# F.Undergrad:Expend       2.462609e-06
# F.Undergrad:Grad.Rate    .
# P.Undergrad:Outstate     .
# P.Undergrad:Room.Board   .
# P.Undergrad:Books        .
# P.Undergrad:Personal     .
# P.Undergrad:PhD          .
# P.Undergrad:Terminal     .
# P.Undergrad:S.F.Ratio    1.758450e-03
# P.Undergrad:perc.alumni  .
# P.Undergrad:Expend       .
# P.Undergrad:Grad.Rate    .
# Outstate:Room.Board      .
# Outstate:Books           .
# Outstate:Personal        .
# Outstate:PhD             .
# Outstate:Terminal        .
# Outstate:S.F.Ratio      -5.630012e-04
# Outstate:perc.alumni     1.348435e-04
# Outstate:Expend          1.621748e-07
# Outstate:Grad.Rate       .
# Room.Board:Books         3.029840e-05
# Room.Board:Personal      .
# Room.Board:PhD           .
# Room.Board:Terminal      .
# Room.Board:S.F.Ratio     1.937805e-03
# Room.Board:perc.alumni   .
# Room.Board:Expend        .
# Room.Board:Grad.Rate     .
# Books:Personal          -1.696466e-04
# Books:PhD                .
# Books:Terminal           .
# Books:S.F.Ratio          2.055988e-02
# Books:perc.alumni        .
# Books:Expend            -1.263093e-05
# Books:Grad.Rate          .
# Personal:PhD             .
# Personal:Terminal        .
# Personal:S.F.Ratio       6.133811e-06
# Personal:perc.alumni     3.560791e-05
# Personal:Expend         -6.628211e-08
# Personal:Grad.Rate       .
# PhD:Terminal             .
# PhD:S.F.Ratio            .
# PhD:perc.alumni          .
# PhD:Expend               .
# PhD:Grad.Rate            .
# Terminal:S.F.Ratio       2.015058e-01
# Terminal:perc.alumni    -4.890811e-02
# Terminal:Expend         -4.153069e-04
# Terminal:Grad.Rate       .
# S.F.Ratio:perc.alumni    .
# S.F.Ratio:Expend         1.315872e-03
# S.F.Ratio:Grad.Rate     -2.265320e-01
# perc.alumni:Expend       1.137915e-03
# perc.alumni:Grad.Rate    .
# Expend:Grad.Rate         .

# %% [markdown]
# ## PCR

# %%
install.packages("pls")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(pls)
# Out:
# Attaching package: ‘pls’
#
#
# The following object is masked from ‘package:stats’:
#
#     loadings

# %%
summary(prcomp(College[,-c(2,1)], scale= T))
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4    PC5     PC6     PC7
# Standard deviation     2.2898 1.9721 1.08153 0.96602 0.9584 0.92026 0.77723
# Proportion of Variance 0.3277 0.2431 0.07311 0.05832 0.0574 0.05293 0.03776
# Cumulative Proportion  0.3277 0.5707 0.64386 0.70219 0.7596 0.81252 0.85028
#                            PC8     PC9    PC10    PC11    PC12    PC13    PC14
# Standard deviation     0.76132 0.72389 0.63446 0.55903 0.46932 0.37991 0.32171
# Proportion of Variance 0.03623 0.03275 0.02516 0.01953 0.01377 0.00902 0.00647
# Cumulative Proportion  0.88650 0.91925 0.94441 0.96394 0.97771 0.98673 0.99320
#                           PC15    PC16
# Standard deviation     0.28463 0.16674
# Proportion of Variance 0.00506 0.00174
# Cumulative Proportion  0.99826 1.00000

# %%
pcr_fit <- pcr(Apps ~ ., data = College, scale = TRUE, validation = "none")
summary(pcr_fit)
# Out:
# Data: 	X dimension: 777 17
# 	Y dimension: 777 1
# Fit method: svdpc
# Number of components considered: 17
# TRAINING: % variance explained
#       1 comps  2 comps  3 comps  4 comps  5 comps  6 comps  7 comps  8 comps
# X      31.670    57.30    64.30    69.90    75.39    80.38    83.99    87.40
# Apps    2.316    73.06    73.07    82.08    84.08    84.11    84.32    85.18
#       9 comps  10 comps  11 comps  12 comps  13 comps  14 comps  15 comps
# X       90.50     92.91     95.01     96.81      97.9     98.75     99.36
# Apps    85.88     86.06     86.06     86.10      86.1     86.13     90.32
#       16 comps  17 comps
# X        99.84    100.00
# Apps     92.52     92.92

# %%
validationplot(pcr_fit , val.type = "MSEP")
# Out:
# Plot with title “Apps”

# %%
# funcion que calcula error de prueba UNA vez para UN valor de M
test_M_pcr <- function(M){ # M representa el número de componentes principales en la regresión
  train <- sample(1:n, ntrain)
  pcr_fit <- pcr(Apps ~ ., data = College, subset = train, scale = TRUE, validation = "none")
  pcr_pred <- predict(pcr_fit , College[-train, ], ncomp = M)
  return(mean((pcr_pred - y[-train])^2))
}
# funcion que calcula error de prueba UNA vez para VARIOS valor de M
test_M_pcr_VEC <- Vectorize(test_M_pcr)

# %%
# funcion que calcula error de prueba B-VECES para VARIOS valor de M
test_M_pcr_B <- function(M, B){
  return(replicate(B, test_M_pcr_VEC(M)))
}

# %%
set.seed(11)
t0 = proc.time()
test_M_2000 <- test_M_pcr_B(M=1:17, B=2000)
proc.time() - t0
#   user  system elapsed   Google-Colab (some power)
#280.324   2.044 282.729
# Out:
#    user  system elapsed
# 280.324   2.044 282.729

# %%
#error de prueba
mean_test_M <- apply(test_M_2000, 1, mean)
wminM <- which.min(mean_test_M)
print(wminM)          #17
min(mean_test_M)      #1305639.34034876
# Out:
# [1] 17
# [1] 1305639

# %%
#error aparente
#1059279.21251667
pcr_fit0 <- pcr(Apps ~ ., data = College, scale = TRUE, validation = "none")
pcr_pred0 <- predict(pcr_fit0, College, ncomp = 17)
mean((pcr_pred0 - y)^2)
# Out:
# [1] 1059279

# %% [markdown]
# ## PLOTS

# %%
par(mfrow = c(1,2))
fit_0 <- glmnet(x, y,alpha = 0, relax = F)
plot(fit_0, xvar = "lambda", label = TRUE)
abline(v=log(val_lambda[wmin_RR]), col="red")
plot(fit_0, xvar = "lambda", label = TRUE, ylim = c(-5,7))
abline(v=log(val_lambda[wmin_RR]), col="red")
# Out:
# plot without title

# %%
pdf("coef_RR.pdf", width = 14, height = 5)

par(mfrow = c(1,2))
fit_0 <- glmnet(x, y,alpha = 0, relax = F)
plot(fit_0, xvar = "lambda", label = TRUE)
abline(v=log(val_lambda[wmin_RR]), col="red")
plot(fit_0, xvar = "lambda", label = TRUE, ylim = c(-5,7))
abline(v=log(val_lambda[wmin_RR]), col="red")

dev.off()
# Out:
# png
#   2

# %%
par(mfrow = c(1,2))
fit_1 <- glmnet(x, y,alpha = 1, relax = F)
plot(fit_1, xvar = "lambda", label = TRUE)
abline(v=log(val_lambda_lasso[wmin_lasso]), col="red")
plot(fit_1, xvar = "lambda", label = TRUE, ylim = c(-7,4))
abline(v=log(val_lambda_lasso[wmin_lasso]), col="red")
# Out:
# plot without title

# %%
pdf("coef_lasso.pdf", width = 14, height = 5)

par(mfrow = c(1,2))
fit_1 <- glmnet(x, y,alpha = 1, relax = F)
plot(fit_1, xvar = "lambda", label = TRUE)
abline(v=log(val_lambda_lasso[wmin_lasso]), col="red")
plot(fit_1, xvar = "lambda", label = TRUE, ylim = c(-7,4))
abline(v=log(val_lambda_lasso[wmin_lasso]), col="red")

dev.off()
# Out:
# png
#   2

# %%
par(mfrow = c(1,2))
fit_05 <- glmnet(x, y,alpha = 0.5, relax = F)
plot(fit_05, xvar = "lambda", label = TRUE)
abline(v=log(val_lambda_elastic[wmin_elastic]), col="red")
plot(fit_05, xvar = "lambda", label = TRUE, ylim = c(-6,2.5))
abline(v=log(val_lambda_elastic[wmin_elastic]), col="red")
# Out:
# plot without title

# %%
pdf("coef_elastic.pdf", width = 14, height = 5)

par(mfrow = c(1,2))
fit_05 <- glmnet(x, y,alpha = 0.5, relax = F)
plot(fit_05, xvar = "lambda", label = TRUE)
abline(v=log(val_lambda_elastic[wmin_elastic]), col="red")
plot(fit_05, xvar = "lambda", label = TRUE, ylim = c(-6,2.5))
abline(v=log(val_lambda_elastic[wmin_elastic]), col="red")

dev.off()
# Out:
# png
#   2

# %%
install.packages("latex2exp")
library(latex2exp)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
par(mfrow = c(1,2))
plot(log(val_lambda), mean_test_lambda_RR, type="b", pch=19, cex=0.7, xlab = TeX("Log($\\lambda$)"), ylab="M.S.E", main="Errores de prueba")
points(log(val_lambda[wmin_RR]), min(mean_test_lambda_RR), col="red", pch=19, cex=0.7)

hist(RR_2000_sim, breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.", freq = T)
abline(v = min(mean_test_lambda_RR), col="red")
# Out:
# Plot with title “Error de prueba, 2000 simulaciones”

# %%
pdf("hist_RR.pdf", width = 12, height = 5)

par(mfrow = c(1,2))
plot(log(val_lambda), mean_test_lambda_RR, type="b", pch=19, cex=0.7, xlab = TeX("Log($\\lambda$)"), ylab="M.S.E", main="Errores de prueba")
points(log(val_lambda[wmin_RR]), min(mean_test_lambda_RR), col="red", pch=19, cex=0.7)

hist(RR_2000_sim, breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.", freq = T)
abline(v = min(mean_test_lambda_RR), col="red")

dev.off()
# Out:
# png
#   2

# %%
par(mfrow = c(1,2))
plot(log(val_lambda_lasso), mean_test_lambda_lasso, type="b", pch=19, cex=0.7, xlab = TeX("Log($\\lambda$)"), ylab="M.S.E", main="Errores de prueba")
points(log(val_lambda_lasso[wmin_lasso]), min(mean_test_lambda_lasso), col="red", pch=19, cex=0.7)

hist(lasso_2000_sim, breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.", freq = T)
abline(v = min(mean_test_lambda_lasso), col="red")
# Out:
# Plot with title “Error de prueba, 2000 simulaciones”

# %%
pdf("hist_lasso.pdf", width = 12, height = 5)

par(mfrow = c(1,2))
plot(log(val_lambda_lasso), mean_test_lambda_lasso, type="b", pch=19, cex=0.7, xlab = TeX("Log($\\lambda$)"), ylab="M.S.E", main="Errores de prueba")
points(log(val_lambda_lasso[wmin_lasso]), min(mean_test_lambda_lasso), col="red", pch=19, cex=0.7)

hist(lasso_2000_sim, breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.", freq = T)
abline(v = min(mean_test_lambda_lasso), col="red")

dev.off()
# Out:
# png
#   2

# %%
par(mfrow = c(1,2))
plot(log(val_lambda_elastic), mean_test_lambda_elastic, type="b", pch=19, cex=0.7, xlab = TeX("Log($\\lambda$)"), ylab="M.S.E", main="Errores de prueba")
points(log(val_lambda_elastic[wmin_elastic]), min(mean_test_lambda_elastic), col="red", pch=19, cex=0.7)

hist(lasso_2000_sim, breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.", freq = T)
abline(v = min(mean_test_lambda_lasso), col="red")
# Out:
# Plot with title “Error de prueba, 2000 simulaciones”

# %%
pdf("hist_elastic.pdf", width = 12, height = 5)

par(mfrow = c(1,2))
plot(log(val_lambda_elastic), mean_test_lambda_elastic, type="b", pch=19, cex=0.7, xlab = TeX("Log($\\lambda$)"), ylab="M.S.E", main="Errores de prueba")
points(log(val_lambda_elastic[wmin_elastic]), min(mean_test_lambda_elastic), col="red", pch=19, cex=0.7)

hist(lasso_2000_sim, breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.", freq = T)
abline(v = min(mean_test_lambda_lasso), col="red")

dev.off()
# Out:
# png
#   2

# %%
par(mfrow = c(1,2))
plot(1:17, mean_test_M, type="b", pch=19, cex=0.7, xlab = "number of components", ylab="M.S.E", main="Errores de prueba")
points(17, min(mean_test_M), col="red", pch=19, cex=0.7)

hist(test_M_2000[17,], breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.")
abline(v = min(mean_test_M), col="red")
# Out:
# Plot with title “Error de prueba, 2000 simulaciones”

# %%
pdf("hist_pcr.pdf", width = 12, height = 5)

par(mfrow = c(1,2))
plot(1:17, mean_test_M, type="b", pch=19, cex=0.7, xlab = "number of components", ylab="M.S.E", main="Errores de prueba")
points(17, min(mean_test_M), col="red", pch=19, cex=0.7)

hist(test_M_2000[17,], breaks = 100, main="Error de prueba, 2000 simulaciones", xlab="M.S.E.")
abline(v = min(mean_test_M), col="red")

dev.off()
# Out:
# png
#   2
